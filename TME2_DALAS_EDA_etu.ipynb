# %% [markdown]
# # Exploratory Data Analysis
#
#
# The objective of this notebook is to explore datasets.
# You will need Pandas, a tutorial is available [here](https://pandas.pydata.org/docs/user_guide/10min.html).
#
#
# Please note that this notebook is inspired from notebooks published by Galiana, Lino. 2023. Python Pour La Data Science. https://doi.org/10.5281/zenodo.8229676.

# %% [markdown]
# ## Dataset
# We consider a dataset gathering information about elections and votes between 2000 and 2016 in the USA. Il also maps economics signals.

# %%
import requests

url = 'https://raw.githubusercontent.com/linogaliana/python-datascientist/master/content/modelisation/get_data.py'
r = requests.get(url, allow_redirects=True)
open('getdata.py', 'wb').write(r.content)

import getdata
votes = getdata.create_votes_dataframes()
votes.head(3)
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 0      29      227  00758566  0500000US29227  29227       Worth   06
# 1      31      061  00835852  0500000US31061  31061    Franklin   06
# 2      36      013  00974105  0500000US36013  36013  Chautauqua   06
#
#         ALAND      AWATER                                           geometry  \
# 0   690564983      493903  POLYGON ((-94.63203 40.57176, -94.53388 40.570...
# 1  1491355860      487899  POLYGON ((-99.17940 40.35068, -98.72683 40.350...
# 2  2746047476  1139407865  POLYGON ((-79.76195 42.26986, -79.62748 42.324...
#
#    ... share_2008_democrat share_2008_other share_2008_republican  \
# 0  ...            0.363714         0.034072              0.602215
# 1  ...            0.284794         0.019974              0.695232
# 2  ...            0.495627         0.018104              0.486269
#
#   share_2012_democrat  share_2012_other  share_2012_republican  \
# 0            0.325382          0.041031               0.633588
# 1            0.250000          0.026042               0.723958
# 2            0.425017          0.115852               0.459131
#
#    share_2016_democrat  share_2016_other  share_2016_republican      winner
# 0             0.186424          0.041109               0.772467  republican
# 1             0.149432          0.045427               0.805140  republican
# 2             0.352012          0.065439               0.582550  republican
#
# [3 rows x 383 columns]

# %% [markdown]
# Q1. What is the size of the dataframe? (number of lines and columns)
#
# Print the column names and their types.
#
# Print the statistics of each numerical column (mean, std, quartile, min, max).

# %%
# #[STUDENT
# print("size of the dataframe: \n", votes.shape)
# print("columns names of the dataframe: \n", votes.columns)
# print("type of the columns of the dataframe: \n", votes.dtypes)
# print("statistical description of the dataframe: \n", votes.describe())
votes.describe()
# Out:
#               ALAND        AWATER     votes_gop     votes_dem   total_votes  \
# count  3.107000e+03  3.107000e+03  3.107000e+03  3.107000e+03  3.107000e+03
# mean   2.462040e+09  1.373998e+08  2.375962e+04  2.598733e+04  5.068057e+04
# std    3.376328e+09  5.432790e+08  5.434766e+04  9.751939e+04  1.502634e+05
# min    5.300262e+06  0.000000e+00  6.000000e+01  4.000000e+00  6.600000e+01
# 25%    1.114608e+09  7.075804e+06  3.674000e+03  1.296500e+03  5.353000e+03
# 50%    1.580933e+09  1.900978e+07  8.291000e+03  3.667000e+03  1.254000e+04
# 75%    2.368309e+09  5.633591e+07  2.071450e+04  1.212150e+04  3.361100e+04
# max    5.197558e+10  1.405367e+10  1.145530e+06  3.028885e+06  4.263443e+06
#
#                diff      per_gop      per_dem  per_point_diff        FIPS_y  \
# count  3.107000e+03  3107.000000  3107.000000     3107.000000   3107.000000
# mean  -2.227707e+03     0.650324     0.332148        0.318176  30666.868040
# std    5.623596e+04     0.160682     0.159230        0.319820  14983.619833
# min   -1.883355e+06     0.053973     0.030909       -0.867524   1001.000000
# 25%    8.595000e+02     0.558025     0.208777        0.136004  19044.000000
# 50%    3.039000e+03     0.683165     0.299395        0.384808  29211.000000
# 75%    7.383000e+03     0.774953     0.422347        0.566318  46006.000000
# max    1.190050e+05     0.961818     0.921497        0.930909  56045.000000
#
#        ...  share_2004_republican  share_2008_democrat  share_2008_other  \
# count  ...            3107.000000          3107.000000       3107.000000
# mean   ...               0.602478             0.414978          0.016538
# std    ...               0.125568             0.138194          0.013338
# min    ...               0.093398             0.049080          0.000000
# 25%    ...               0.522288             0.313901          0.010007
# 50%    ...               0.607826             0.410865          0.015311
# 75%    ...               0.689305             0.504031          0.020431
# max    ...               0.919736             0.924571          0.347630
#
#        share_2008_republican  share_2012_democrat  share_2012_other  \
# count            3107.000000          3107.000000       3107.000000
# mean                0.568484             0.383916          0.019784
# std                 0.137712             0.146793          0.013975
# min                 0.065326             0.034483          0.000000
# 25%                 0.478554             0.277425          0.012204
# 50%                 0.572294             0.371034          0.017327
# 75%                 0.668634             0.473844          0.024333
# max                 0.926380             0.909131          0.121634
#
#        share_2012_republican  share_2016_democrat  share_2016_other  \
# count            3107.000000          3107.000000       3107.000000
# mean                0.596300             0.314797          0.051851
# std                 0.148073             0.151971          0.030405
# min                 0.071934             0.031447          0.003344
# 25%                 0.503178             0.203321          0.031734
# 50%                 0.607998             0.282595          0.047449
# 75%                 0.702955             0.398458          0.065851
# max                 0.958621             0.908638          0.356501
#
#        share_2016_republican
# count            3107.000000
# mean                0.633004
# std                 0.156482
# min                 0.040875
# 25%                 0.544812
# 50%                 0.663534
# 75%                 0.749155
# max                 0.960334
#
# [8 rows x 364 columns]

# %% [markdown]
# Q2. What are the different values of the 'winner' variable? Recode this values into numbers 1,2,3,... and store this encoding in a new variable "winner2".

# %%
print("differente values of the column 'winner' of the dataframe: \n", votes['winner'].unique())
votes['winner2'] = votes['winner'].astype('category').cat.codes 
votes[['winner', 'winner2']].head(10)
# Out:
# differente values of the column 'winner' of the dataframe:
#  ['republican' 'democrats']
#        winner  winner2
# 0  republican        1
# 1  republican        1
# 2  republican        1
# 3   democrats        0
# 4  republican        1
# 5   democrats        0
# 6   democrats        0
# 7  republican        1
# 8  republican        1
# 9  republican        1

# %% [markdown]
# ## Descriptive analysis
#
#
# Q3. Create a dataframe including only those variables: "winner", "votes_gop",
#           'Unemployment_rate_2019', 'Median_Household_Income_2019',
#           'Percent of adults with less than a high school diploma, 2015-19',
#           "Percent of adults with a bachelor's degree or higher, 2015-19".
# Keep the index "GEOID" as index of your dataframe. (use *set_index*).

# %%
new_votes = votes[["GEOID","winner", "votes_gop",
          'Unemployment_rate_2019', 'Median_Household_Income_2019',
          'Percent of adults with less than a high school diploma, 2015-19',
          "Percent of adults with a bachelor's degree or higher, 2015-19"]]
new_votes.set_index("GEOID", inplace = True)
new_votes.head(5)
# Out:
#            winner  votes_gop  Unemployment_rate_2019  \
# GEOID
# 29227  republican        877                     2.7
# 31061  republican       1437                     3.4
# 36013  republican      34853                     4.7
# 37181   democrats       8391                     5.8
# 47183  republican      10396                     4.0
#
#        Median_Household_Income_2019  \
# GEOID
# 29227                       45023.0
# 31061                       49659.0
# 36013                       50143.0
# 37181                       40450.0
# 47183                       42506.0
#
#        Percent of adults with less than a high school diploma, 2015-19  \
# GEOID
# 29227                                          10.169492
# 31061                                           7.534552
# 36013                                          11.192287
# 37181                                          19.596169
# 47183                                          14.861343
#
#        Percent of adults with a bachelor's degree or higher, 2015-19
# GEOID
# 29227                                          20.000000
# 31061                                          17.298262
# 36013                                          22.248287
# 37181                                          14.845985
# 47183                                          21.561512

# %% [markdown]
# Q4. Create a frequency tab for each winner value. Build the plot with horizontal bars illustrating this frequency.

# %%
print(new_votes['winner'].value_counts())
new_votes['winner'].value_counts().plot(kind='bar', title ="winner", figsize=(5, 5), legend=True, fontsize=12, color='red')
# Out:
# republican    2574
# democrats      533
# Name: winner, dtype: int64
# <Axes: title={'center': 'winner'}>

# %% [markdown]
# Q5. Let's consider the 'Median_Household_Income_2019' variable. Transform this variable into a categorical one with 5 five labels. Create the frequency tabl and the associated graph.

# %%
import pandas as pd
new_votes['Income_Category']  = pd.cut(new_votes['Median_Household_Income_2019'], bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
print(new_votes['Income_Category'].value_counts())
new_votes['Income_Category'].value_counts().sort_index().plot(kind='bar', title ="Median_Household_Income_2019", figsize=(6, 5), legend=True, fontsize=12, color='pink', rot=0)
# Out:
# C:\Users\Saliou\AppData\Local\Temp\ipykernel_34012\3559354690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_votes['Income_Category']  = pd.cut(new_votes['Median_Household_Income_2019'], bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
# Low          1676
# Very Low     1183
# Medium        196
# High           47
# Very High       5
# Name: Income_Category, dtype: int64
# <Axes: title={'center': 'Median_Household_Income_2019'}>

# %% [markdown]
# Q6. Provide descriptive statistics of all variables in the dataframe.

# %%
new_votes.describe()
# Out:
#           votes_gop  Unemployment_rate_2019  Median_Household_Income_2019  \
# count  3.107000e+03             3107.000000                   3107.000000
# mean   2.375962e+04                3.960541                  55583.874799
# std    5.434766e+04                1.386941                  14437.596514
# min    6.000000e+01                0.700000                  24732.000000
# 25%    3.674000e+03                3.000000                  46180.000000
# 50%    8.291000e+03                3.700000                  53245.000000
# 75%    2.071450e+04                4.600000                  61791.000000
# max    1.145530e+06               18.300000                 151806.000000
#
#        Percent of adults with less than a high school diploma, 2015-19  \
# count                                        3107.000000
# mean                                           13.087639
# std                                             6.263789
# min                                             1.116910
# 25%                                             8.492852
# 50%                                            11.739810
# 75%                                            16.710670
# max                                            73.560211
#
#        Percent of adults with a bachelor's degree or higher, 2015-19
# count                                        3107.000000
# mean                                           21.957299
# std                                             9.582583
# min                                             0.000000
# 25%                                            15.324092
# 50%                                            19.552057
# 75%                                            25.962418
# max                                            77.557411

# %% [markdown]
# Q7. Build an histogram for the variables vote_gop.

# %%
new_votes['votes_gop'].value_counts().sort_index().plot(kind='bar', title ="votes_gop", figsize=(6, 5), legend=True, fontsize=12, color='pink', rot=0)
# Out:
# <Axes: title={'center': 'votes_gop'}>

# %% [markdown]
# Q8. Extract the correlation matrix. Graph it by using the seaborn package and its heatmap function.
# Plot a matrix of point clouds of df2 variables with pd.plotting.scatter_matrix.
# Interpret

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = new_votes.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\Saliou\AppData\Local\Temp\ipykernel_34012\365256964.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = new_votes.corr()

# %% [markdown]
# ## Visualization with maps
#
#
# Q9. Below, we have two blocks of code generating two different graphs (the first map is a choropleth card). They use the same dataset but have different shapes. Comment these graphs and the differences.

# %%
# republican : red, democrat : blue
color_dict = {'republican': '#FF0000', 'democrats': '#0000FF'}

fig, ax = plt.subplots(figsize = (12,12))
grouped = votes.groupby('winner')
for key, group in grouped:
    group.plot(ax=ax, column='winner', label=key, color=color_dict[key])
plt.axis('off')
# Out:
# C:\Users\Saliou\AppData\Local\Temp\ipykernel_34012\2075903446.py:7: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   group.plot(ax=ax, column='winner', label=key, color=color_dict[key])
# C:\Users\Saliou\AppData\Local\Temp\ipykernel_34012\2075903446.py:7: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   group.plot(ax=ax, column='winner', label=key, color=color_dict[key])
# (-127.6146362, -64.0610978, 23.253819649999997, 50.628669349999996)

# %%
import plotly
import plotly.graph_objects as go
import pandas as pd
import geopandas as gpd
import numpy as np


centroids = votes.copy()
centroids.geometry = centroids.centroid
centroids['size'] = centroids['CENSUS_2010_POP'] / 10000  # to get reasonable plotable number

color_dict = {"republican": '#FF0000', 'democrats': '#0000FF'}
centroids["winner"] =  np.where(centroids['votes_gop'] > centroids['votes_dem'], 'republican', 'democrats')


centroids['lon'] = centroids['geometry'].x
centroids['lat'] = centroids['geometry'].y
centroids = pd.DataFrame(centroids[["county_name",'lon','lat','winner', 'CENSUS_2010_POP',"state_name"]])
groups = centroids.groupby('winner')

df = centroids.copy()

df['color'] = df['winner'].replace(color_dict)
df['size'] = df['CENSUS_2010_POP']/6000
df['text'] = df['CENSUS_2010_POP'].astype(int).apply(lambda x: '<br>Population: {:,} people'.format(x))
df['hover'] = df['county_name'].astype(str) +  df['state_name'].apply(lambda x: ' ({}) '.format(x)) + df['text']

fig_plotly = go.Figure(
  data=go.Scattergeo(
  locationmode = 'USA-states',
  lon=df["lon"], lat=df["lat"],
  text = df["hover"],
  mode = 'markers',
  marker_color = df["color"],
  marker_size = df['size'],
  hoverinfo="text"
  )
)

fig_plotly.update_traces(
  marker = {'opacity': 0.5, 'line_color': 'rgb(40,40,40)', 'line_width': 0.5, 'sizemode': 'area'}
)

fig_plotly.update_layout(
  title_text = "Reproduction of the \"Acres don't vote, people do\" map <br>(Click legend to toggle traces)",
  showlegend = True,
  geo = {"scope": 'usa', "landcolor": 'rgb(217, 217, 217)'}
)
# Out:
# C:\Users\Saliou\AppData\Local\Temp\ipykernel_34012\1538029200.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids.geometry = centroids.centroid

# %% [markdown]
# ## Normalization
#
# Q10. Standardize all variables in the dataframe (do not overwrite the values!) and look at the histogram of variable 'the Median_Household_Income_2019 variable' before/after standardization.

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()

# Standardize all variables without overwriting the original DataFrame
df2_standardized = pd.DataFrame(scaler.fit_transform(new_votes.iloc[:,1:-1]), columns=new_votes.columns[1:-1])

# Plot histogram of 'Median_Household_Income_2019' before standardization
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
new_votes['Median_Household_Income_2019'].hist()
plt.title('Before Standardization')

# Plot histogram of 'Median_Household_Income_2019' after standardization
plt.subplot(1, 2, 2)
df2_standardized['Median_Household_Income_2019'].hist()
plt.title('After Standardization')

plt.show()

# %% [markdown]
# Q11. Verify that the distribution centered at zero, and that the empirical variance is indeed equal to 1.

# %%
mean = df2_standardized['Median_Household_Income_2019'].mean()
variance = df2_standardized['Median_Household_Income_2019'].var()

print("Mean:", mean)
print("Variance:", variance)
# Out:
# Mean: 1.829527481841262e-16
# Variance: 1.0003219575016065

# %% [markdown]
# Q12. Create scaler, a Transformer that you build on the first 1000 rows of your df2 DataFrame with the exception of the variable to be explained winner. Check the mean and standard deviation of each column on these same observations. The parameters that will be used for later standardization are stored in the .mean_ and .scale_ attributes.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit the scaler on the first 1000 rows excluding the 'winner' column
scaler.fit(df2_standardized.iloc[:1000])

# Check the mean and standard deviation of each column on these same observations
means = scaler.mean_
std_devs = scaler.scale_

print("Means:", means)
print("Standard Deviations:", std_devs)
# Out:
# Means: [-0.11774198 -0.08310319 -0.02734689 -0.01927644 -0.03923952]
# Standard Deviations: [0.60352628 0.92909538 0.92266736 1.0302349  0.98180243]

# %% [markdown]
# # Outlier detection
#
# Q13. Plot the distribution of each variable in a boxplot and analyze them. Do you see outliers?

# %%
col = [i for i in df2_standardized.columns]

# %%
df2_standardized.boxplot(column=col, figsize=(20, 15))
# Out:
# <Axes: >

# %% [markdown]
# Q14. Identify, for each variable, individuals that are not include within the window +/- 3*std. How many lines would you remove in total?

# %%
outliers = df2_standardized.apply(lambda x: np.abs(x - x.mean()) > 3*x.std())

# Compter le nombre total de lignes qui seraient supprimées
num_rows_to_remove = outliers.any(axis=1).sum()

print("Number of rows to remove:", num_rows_to_remove)
# Out:
# Number of rows to remove: 200

# %% [markdown]
# Q15. Let's process over all variables with a library: you can import and use the IsolationForest function from the sklearn.ensemble package.
# Change the different parameter values to identify their impact.
# Do you obtain results different from the analysis of single variables.

# %%
from sklearn.ensemble import IsolationForest

clf = IsolationForest(contamination=0.06)  
outliers = clf.fit_predict(df2_standardized)

# Les outliers sont marqués avec -1
num_outliers = (outliers == -1).sum()

print("Number of outliers detected:", num_outliers)
# Out:
# Number of outliers detected: 187

# %% [markdown]
# Q16. Display in a scatter plot variables 'votes_gop' and 'Unemployment_rate_2019' and color points according whether they are outliers or not. Interpret.
# You can change pairs of variables.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
outliers_bool = outliers == -1

plt.scatter(df2_standardized['votes_gop'], df2_standardized['Unemployment_rate_2019'], c=outliers_bool)
plt.xlabel('votes_gop')
plt.ylabel('Unemployment_rate_2019')
plt.title('Scatter plot with outliers colored')
plt.show()

# %% [markdown]
# Q17. Display for all pairs of variables using pairplot from seaborn.

# %%
sns.pairplot(df2_standardized)
plt.show()
