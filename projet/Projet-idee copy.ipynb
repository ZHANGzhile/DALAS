# %% [markdown]
# # Project l’impact des aliment sur l’environnement, de la production à la mise en vente

# %%
import pandas as pd
import projet_craber as craber
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ing = pd.read_csv("agribalyse-31-detail-par-ingredient.csv")
df_eta = pd.read_csv("agribalyse-31-detail-par-etape.csv")
df_syn = pd.read_csv("agribalyse-31-synthese.csv")

print(df_ing.shape)
print(df_eta.shape)
print(df_syn.shape)
# Out:
# (8840, 27)
# (2500, 116)
# (2500, 32)

# %% [markdown]
# ## Pretraitement des données

# %%
df_synt = df_syn.drop_duplicates(subset=["Code CIQUAL"], keep="first")
df_etape = df_eta.drop_duplicates(subset=["Code CIQUAL"], keep="first")

# %%
# remplissage des valeurs nulles
float_columns = df_synt.select_dtypes(include="float64").columns
float_columns_eta = df_eta.select_dtypes(include="float64").columns

# Traversée la data frame, remplissez les valeurs nulles comme moye
for column in float_columns:
    mean_value = df_synt[column].mean()
    df_synt[column].fillna(mean_value, inplace=True)

for column in float_columns_eta:
    mean_value = df_eta[column].mean()
    df_eta[column].fillna(mean_value, inplace=True)

# supprimer les lignes avec des strings vide
df_synt = df_synt.dropna()
df_eta = df_eta.dropna()


# Définir un seuil de 1.96 écarts types (intervalle de confiance à 95 %)


# threshold = 1.96

# # Calculer la moyenne et l'écart type
# mean = np.mean(df_synt["DQR"])
# std = np.std(df_synt["DQR"])

# # Calculer les bornes de l'intervalle de confiance
# low_bound = mean - std * threshold

# Filtrer les lignes avec des valeurs dans l'intervalle de confiance
df_synt = df_synt[df_synt["DQR"] <= 4]

# # Définir un seuil de 3 écarts types
# threshold = 3
# float_columns = float_columns.drop("Score unique EF", errors="ignore")
# float_columns = float_columns.drop("DQR", errors="ignore")

# for column in float_columns:
#     mean = np.mean(df_synt[column])
#     std = np.std(df_synt[column])
#     low_bound = mean - std * threshold
#     upper_bound = mean + std * threshold

#     df_synt[column] = np.where(df_synt[column] < low_bound, low_bound, df_synt[column])
#     df_synt[column] = np.where(
#         df_synt[column] > upper_bound, upper_bound, df_synt[column]
#     )

# %%
df_synt.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'code saison', 'code avion',
#        'Livraison', 'Matériau d'emballage', 'Préparation', 'DQR',
#        'Score unique EF', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine   substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine   substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux', ' id', ' i', ' rand'],
#       dtype='object')

# %%
# Histogramme du 'Score unique EF'
plt.figure(figsize=(10, 6))
sns.histplot(df_synt["Score unique EF"], kde=True)
plt.title("Distribution du Score unique EF")
plt.xlabel("Score unique EF")
plt.ylabel("Fréquence")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from warnings import filterwarnings


scaler = MinMaxScaler()
X = df_synt.iloc[:, 12:-3]
X = scaler.fit_transform(X)
X = pd.DataFrame(X, columns=df_synt.columns[12:-3])

# %%
filterwarnings("ignore")
inertia = []
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X.values.reshape(-1, 1))
    inertia.append(kmeans.inertia_)
plt.figure()
plt.plot(range(1, 20), inertia, marker="o")
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
tab20 = sns.color_palette("tab20", as_cmap=True)

tsne = TSNE()
tsne_data = tsne.fit_transform(X)

km = KMeans(n_clusters=5)
pred = km.fit_predict(X)

# afficher avec des couleur et des legendes
df = pd.DataFrame(tsne_data, columns=["x", "y"])
df["cluster"] = pred
sns.scatterplot(data=df, x="x", y="y", hue="cluster", palette=tab20)
plt.show()

# %%
df_synt["cluster"] = pred  # Ajoutez les prédictions de cluster au DataFrame

# Créez un dictionnaire pour stocker les aliments par cluster
clusters = {}
for i in range(km.n_clusters):
    # Sélectionner les noms des aliments et les scores EF pour chaque cluster
    clusters[i] = (
        df_synt[df_synt["cluster"] == i][["Sous-groupe d'aliment", "Score unique EF"]]
        .drop_duplicates()
        .values.tolist()
    )

# Calculer la moyenne des scores EF pour chaque cluster
moyennes_clusters = {}
for cluster, aliments_scores in clusters.items():
    # Calculer la moyenne des scores EF pour le cluster actuel
    moyenne_ef = sum(score for _, score in aliments_scores) / len(aliments_scores)
    moyennes_clusters[cluster] = moyenne_ef

# %%
clusters
# Out:
# {0: [['algues', 1.2260253],
#   ['algues', 1.1994911],
#   ['épices', 1.3171905],
#   ['épices', 1.3159399],
#   ['aides culinaires', 2.0695637],
#   ['épices', 1.3175941],
#   ['épices', 0.83199636],
#   ['sauces', 1.2062024],
#   ['laits et boissons infantiles', 1.5318759],
#   ['boissons sans alcool', 1.2630745],
#   ['boissons sans alcool', 1.0337388],
#   ['boissons sans alcool', 1.0294469],
#   ['boissons sans alcool', 1.8358611],
#   ['boissons sans alcool', 0.80494265],
#   ['boissons sans alcool', 0.82242627],
#   ['boissons sans alcool', 1.3067005],
#   ['feuilletées et autres entrées', 0.8437435799999999],
#   ['plats composés', 1.5480003],
#   ['plats composés', 1.1407868],
#   ['sandwichs', 1.0410813],
#   ['pizzas, tartes et crêpes salées', 0.834032],
#   ['plats composés', 0.84048809],
#   ['sandwichs', 1.7187724],
#   ['plats composés', 1.7808887],
#   ['plats composés', 0.96259975],
#   ['plats composés', 1.5849314],
#   ['plats composés', 0.69331252],
#   ['feuilletées et autres entrées', 1.3216288],
#   ['pizzas, tartes et crêpes salées', 1.1291034],
#   ['plats composés', 1.0917965],
#   ['sandwichs', 1.7034247],
#   ['sandwichs', 0.8007360800000001],
#   ['plats composés', 0.7089422200000001],
#   ['plats composés', 1.3890033000000002],
#   ['plats composés', 1.4180682],
#   ['plats composés', 1.7723592],
#   ['plats composés', 0.99763514],
#   ['pizzas, tartes et crêpes salées', 0.76026177],
#   ['plats composés', 1.2541093],
#   ['plats composés', 1.5139134],
#   ['plats composés', 1.6026965],
#   ['plats composés', 0.8885229],
#   ['plats composés', 0.3890320399999999],
#   ['salades composées et crudités', 0.80365382],
#   ['sandwichs', 1.3541202],
#   ['soupes', 0.44705246],
#   ['soupes', 0.41233945],
#   ['feuilletées et autres entrées', 0.42628472],
#   ['plats composés', 0.73445025],
#   ['pizzas, tartes et crêpes salées', 1.4782097],
#   ['plats composés', 0.97482646],
#   ['fruits', 0.90847693],
#   ['fruits à coque et graines oléagineuses', 0.85461776],
#   ['fruits à coque et graines oléagineuses', 0.87687937],
#   ['légumes', 1.1531033],
#   ['fruits', 4.3370642],
#   ['fruits', 2.005173],
#   ['légumes', 1.7886035],
#   ['fromages', 1.006771],
#   ['fromages', 0.91676459],
#   ['fromages', 1.1642821],
#   ['fromages', 1.0576641999999998],
#   ['fromages', 1.119279],
#   ['fromages', 0.8267582099999999],
#   ['fromages', 0.9055138],
#   ['fromages', 0.87507933],
#   ['fromages', 0.74800281],
#   ['fromages', 0.90551398],
#   ['fromages', 0.8380091900000001],
#   ['fromages', 0.93926619],
#   ['fromages', 0.83465212],
#   ['laits', 1.527918],
#   ['fromages', 1.0967774],
#   ['fromages', 0.95051699],
#   ['fromages', 0.8830122],
#   ['fromages', 0.7656641000000001],
#   ['produits laitiers frais et assimilés', 1.6408773],
#   ['fromages', 0.97301858],
#   ['beurres', 0.7292086600000001],
#   ['beurres', 0.73447905],
#   ['huiles et graisses végétales', 1.2913296],
#   ['huiles et graisses végétales', 0.98179023],
#   ['huiles et graisses végétales', 1.364513],
#   ['beurres', 0.7343835599999999],
#   ['huiles et graisses végétales', 1.5696508],
#   ['pâtes, riz et céréales', 1.6323897],
#   ['chocolats et produits à base de chocolat', 0.76670782],
#   ['chocolats et produits à base de chocolat', 0.74293636],
#   ['chocolats et produits à base de chocolat', 0.8790444900000001],
#   ['produits à base de poissons et produits de la mer', 0.91253695],
#   ['charcuteries', 2.0536805],
#   ['charcuteries', 2.0222485],
#   ['poissons crus', 1.8926601],
#   ['poissons cuits', 2.3395643],
#   ['produits à base de poissons et produits de la mer', 0.43228172],
#   ['charcuteries', 1.9336215],
#   ['autres produits à base de viande', 0.97319849],
#   ['autres produits à base de viande', 1.1795419],
#   ['autres produits à base de viande', 1.0046305],
#   ['viandes cuites', 1.1942020999999998],
#   ['produits à base de poissons et produits de la mer', 0.89166172],
#   ['mollusques et crustacés cuits', 1.0992664],
#   ['mollusques et crustacés crus', 0.90444911],
#   ['mollusques et crustacés cuits', 1.0915759],
#   ['viandes crues', 0.87831147],
#   ['charcuteries', 1.2239837],
#   ['viandes crues', 1.1795419],
#   ['viandes cuites', 1.1795419],
#   ['poissons crus', 0.8108275500000001],
#   ['poissons crus', 1.3648377],
#   ['poissons cuits', 1.6950626],
#   ['charcuteries', 0.99031542],
#   ['charcuteries', 0.73821523],
#   ['viandes crues', 1.6900811],
#   ['charcuteries', 1.2386832],
#   ['viandes crues', 0.88379581],
#   ['viandes cuites', 1.2014627],
#   ['charcuteries', 0.95754979],
#   ['charcuteries', 0.87422758],
#   ['charcuteries', 0.84279555],
#   ['charcuteries', 1.2441833],
#   ['mollusques et crustacés crus', 1.3269935],
#   ['autres produits à base de viande', 0.79909053],
#   ['mollusques et crustacés crus', 0.94251642],
#   ['mollusques et crustacés crus', 0.64627035],
#   ['charcuteries', 0.96866364],
#   ['charcuteries', 0.8672376900000001],
#   ['viandes crues', 0.8770146600000001],
#   ['autres produits à base de viande', 0.85109148],
#   ['viandes crues', 0.8672376900000001],
#   ['viandes cuites', 1.1632533],
#   ['viandes cuites', 0.95827238],
#   ['poissons crus', 1.2350042],
#   ['poissons cuits', 1.018584],
#   ['viandes cuites', 1.1634458],
#   ['charcuteries', 0.97649216],
#   ['poissons crus', 1.1373759],
#   ['autres produits à base de viande', 1.6072008999999998],
#   ['charcuteries', 1.1795419],
#   ['charcuteries', 1.2140168999999998],
#   ['charcuteries', 1.2017628],
#   ['charcuteries', 0.86527927],
#   ['charcuteries', 1.124502],
#   ['poissons crus', 0.97992681],
#   ['poissons cuits', 1.2250640000000002],
#   ['poissons crus', 0.69770748],
#   ['produits à base de poissons et produits de la mer', 0.90648635],
#   ['produits à base de poissons et produits de la mer', 0.90655912],
#   ['poissons crus', 1.1417634],
#   ['poissons crus', 1.209417],
#   ['produits à base de poissons et produits de la mer', 0.77375618],
#   ['produits à base de poissons et produits de la mer', 0.97532005],
#   ['charcuteries', 1.2950216],
#   ['produits à base de poissons et produits de la mer', 0.65728362],
#   ['charcuteries', 0.88181873],
#   ['charcuteries', 0.77323521],
#   ['poissons crus', 3.0712124],
#   ['œufs', 0.7184558600000001],
#   ['poissons cuits', 5.3935651],
#   ['charcuteries', 0.7605308700000001],
#   ['charcuteries', 0.80582851],
#   ['charcuteries', 1.5925721],
#   ['mollusques et crustacés crus', 1.3295576],
#   ['poissons cuits', 3.778645],
#   ['produits à base de poissons et produits de la mer', 0.8670672599999999],
#   ['charcuteries', 0.8658079200000001],
#   ['viandes crues', 1.4639868],
#   ['viandes cuites', 1.8808234],
#   ['viandes crues', 1.4566141],
#   ['viandes cuites', 1.8715098],
#   ['viandes crues', 1.1686396],
#   ['viandes cuites', 1.507724],
#   ['viandes crues', 0.86527927],
#   ['viandes crues', 1.823955],
#   ['autres produits à base de viande', 0.8437435799999999],
#   ['autres produits à base de viande', 1.1915104],
#   ['autres produits à base de viande', 0.91876221],
#   ['charcuteries', 0.82376912],
#   ['charcuteries', 0.85520116],
#   ['charcuteries', 0.7443735300000001],
#   ['charcuteries', 0.77580556],
#   ['produits à base de poissons et produits de la mer', 1.2034104],
#   ['poissons crus', 1.348515],
#   ['charcuteries', 1.5032449],
#   ['charcuteries', 0.85151765],
#   ['produits à base de poissons et produits de la mer', 0.86774937],
#   ['charcuteries', 1.1360937],
#   ['charcuteries', 1.3612617],
#   ['charcuteries', 1.10418],
#   ['charcuteries', 2.0835206],
#   ['charcuteries', 1.5405715],
#   ['charcuteries', 1.597093],
#   ['charcuteries', 1.4337616],
#   ['charcuteries', 1.0960993],
#   ['poissons cuits', 1.0329441],
#   ['produits à base de poissons et produits de la mer', 1.1633433],
#   ['poissons cuits', 0.8980498400000001],
#   ['poissons cuits', 0.91066644],
#   ['poissons cuits', 0.87923441],
#   ['poissons cuits', 0.8931951],
#   ['poissons cuits', 1.2326165],
#   ['charcuteries', 0.96755137],
#   ['charcuteries', 0.8185328500000001],
#   ['produits à base de poissons et produits de la mer', 0.85211002],
#   ['produits à base de poissons et produits de la mer', 0.67985252],
#   ['poissons crus', 0.7223413399999999],
#   ['poissons crus', 0.71831291],
#   ['produits à base de poissons et produits de la mer', 0.85209972],
#   ['produits à base de poissons et produits de la mer', 1.2041743],
#   ['poissons cuits', 0.91053722],
#   ['poissons crus', 1.2459604999999998],
#   ['poissons cuits', 1.5385859],
#   ['poissons cuits', 1.5499066],
#   ['viandes crues', 1.3941748],
#   ['viandes cuites', 1.7756428],
#   ['viandes crues', 1.7459059],
#   ['viandes cuites', 1.7828513],
#   ['autres produits à base de viande', 1.7723221],
#   ['viandes crues', 1.7348321]],
#  1: [['boissons sans alcool', 2.0715283],
#   ['plats composés', 2.1029315],
#   ['plats composés', 2.2907913],
#   ['plats composés', 2.6045077],
#   ['plats composés', 2.9141660000000003],
#   ['feuilletées et autres entrées', 2.3045214],
#   ['plats composés', 3.0846031],
#   ['plats composés', 2.2040399],
#   ['plats composés', 1.9580764],
#   ['viandes crues', 3.6590455],
#   ['viandes crues', 2.601041],
#   ['viandes cuites', 3.317215],
#   ['viandes cuites', 3.3002248],
#   ['viandes crues', 2.6023379],
#   ['viandes cuites', 3.3018675],
#   ['viandes cuites', 3.3188532],
#   ['autres produits à base de viande', 2.9796759],
#   ['viandes crues', 2.6121148],
#   ['viandes cuites', 3.3142193],
#   ['viandes cuites', 3.3254874],
#   ['viandes cuites', 2.6582468],
#   ['viandes crues', 3.2544887],
#   ['viandes cuites', 3.331204],
#   ['viandes crues', 3.2166977],
#   ['autres produits à base de viande', 3.317215],
#   ['viandes crues', 2.3914053],
#   ['viandes cuites', 3.3093498],
#   ['viandes cuites', 2.3480393],
#   ['viandes crues', 2.062746],
#   ['viandes cuites', 2.858854],
#   ['charcuteries', 2.4202142],
#   ['mollusques et crustacés cuits', 1.1449589],
#   ['charcuteries', 3.3080757],
#   ['charcuteries', 2.5638316000000003],
#   ['charcuteries', 2.8637397],
#   ['viandes crues', 2.9924439],
#   ['charcuteries', 2.0843046000000003],
#   ['viandes cuites', 2.915796],
#   ['viandes crues', 2.1157887000000004],
#   ['viandes cuites', 2.3322797],
#   ['viandes crues', 2.5786352000000003],
#   ['viandes crues', 2.5816198],
#   ['viandes cuites', 2.2312431],
#   ['viandes cuites', 2.2199749]],
#  2: [['herbes', 0.064652051],
#   ['herbes', 0.1315805599999999],
#   ['ingrédients divers', 0.21758125],
#   ['ingrédients divers', 0.14641667],
#   ['herbes', 0.39723177],
#   ['ingrédients divers', 0.22008005],
#   ['herbes', 0.090675554],
#   ['herbes', 0.1089281399999999],
#   ['épices', 0.12981155],
#   ['sauces', 0.21492564],
#   ['herbes', 0.11462818],
#   ['sels', 0.078543661],
#   ['ingrédients divers', 0.24452345],
#   ['épices', 0.0766040009999999],
#   ['sauces', 0.31411394],
#   ['sauces', 0.29005398],
#   ['herbes', 0.40053848],
#   ['sauces', 0.16880909],
#   ['sauces', 0.14632883],
#   ['ingrédients divers', 0.52721804],
#   ['ingrédients divers', 0.41928163],
#   ['ingrédients divers', 0.4289488099999999],
#   ['sauces', 0.45353566],
#   ['herbes', 0.25076927],
#   ['ingrédients divers', 0.2630390999999999],
#   ['condiments', 0.30998072],
#   ['condiments', 0.29599382],
#   ['épices', 0.14350739],
#   ['condiments', 0.13091212],
#   ['épices', 0.4556189],
#   ['herbes', 0.1854396],
#   ['herbes', 0.7169294900000001],
#   ['aides culinaires', 0.14641667],
#   ['aides culinaires', 0.14353725],
#   ['herbes', 0.08333266],
#   ['sauces', 0.24321725],
#   ['sauces', 0.23237477],
#   ['sauces', 0.22682843],
#   ['sauces', 0.16365917],
#   ['sauces', 0.56386302],
#   ['sauces', 0.3821898999999999],
#   ['sauces', 0.3862236799999999],
#   ['sauces', 0.46087836],
#   ['sauces', 0.38026368],
#   ['sauces', 0.11483607],
#   ['sauces', 0.38901562],
#   ['sauces', 0.1377233199999999],
#   ['sauces', 0.19344109],
#   ['sauces', 0.18940731],
#   ['sauces', 0.27348936],
#   ['sauces', 0.18389249],
#   ['sauces', 0.53545403],
#   ['sauces', 0.53902641],
#   ['sauces', 0.22231964],
#   ['sauces', 0.21355444],
#   ['sauces', 0.5505116800000001],
#   ['sauces', 0.2188708499999999],
#   ['sauces', 0.36934632],
#   ['sauces', 0.60989951],
#   ['sauces', 0.29431851],
#   ['sauces', 0.37338009],
#   ['sauces', 0.6400357299999999],
#   ['sauces', 0.183557],
#   ['sauces', 0.23843279],
#   ['sauces', 0.51603263],
#   ['sauces', 0.23536279],
#   ['sauces', 0.1441159099999999],
#   ['sauces', 0.44865308],
#   ['sauces', 0.40061918],
#   ['sauces', 0.099173538],
#   ['sauces', 0.2006914],
#   ['sauces', 0.21446629],
#   ['sauces', 0.17205267],
#   ['sauces', 0.17437803],
#   ['sauces', 0.20198804],
#   ['sauces', 0.21748254],
#   ['sauces', 0.40061439],
#   ['ingrédients divers', 0.66153065],
#   ['ingrédients divers', 0.24601642],
#   ['ingrédients divers', 0.082990289],
#   ['ingrédients divers', 0.12609868],
#   ['ingrédients divers', 0.043475704],
#   ['ingrédients divers', 0.070828431],
#   ['ingrédients divers', 0.49341556],
#   ['denrées destinées à une alimentation particulière', 0.26721741],
#   ['condiments', 0.3180959299999999],
#   ['ingrédients divers', 0.13058063],
#   ['épices', 0.25075894],
#   ['condiments', 0.18660839],
#   ['condiments', 0.12700261],
#   ['céréales et biscuits infantiles', 0.31569195],
#   ['laits et boissons infantiles', 0.19936392],
#   ['laits et boissons infantiles', 0.18700214],
#   ['laits et boissons infantiles', 0.19103592],
#   ['céréales et biscuits infantiles', 0.54733219],
#   ['desserts infantiles', 0.1705831],
#   ['laits et boissons infantiles', 0.14466459],
#   ['laits et boissons infantiles', 0.13163249],
#   ['desserts infantiles', 0.11179913],
#   ['petits pots salés et plats infantiles', 0.12969343],
#   ['petits pots salés et plats infantiles', 0.14734724],
#   ['petits pots salés et plats infantiles', 0.32670323],
#   ['petits pots salés et plats infantiles', 0.14036472],
#   ['petits pots salés et plats infantiles', 0.073046465],
#   ['petits pots salés et plats infantiles', 0.086558389],
#   ['boisson alcoolisées', 0.11669762],
#   ['boisson alcoolisées', 0.16441423],
#   ['boisson alcoolisées', 0.1227087799999999],
#   ['boissons sans alcool', 0.07778404],
#   ['boissons sans alcool', 0.061251508],
#   ['boissons sans alcool', 0.17267454],
#   ['boissons sans alcool', 0.14577517],
#   ['boissons sans alcool', 0.0611398829999999],
#   ['boissons sans alcool', 0.050783593],
#   ['boissons sans alcool', 0.2191643],
#   ['boissons sans alcool', 0.046553064],
#   ['boissons sans alcool', 0.04389879],
#   ['boissons sans alcool', 0.10104288],
#   ['boissons sans alcool', 0.1322457199999999],
#   ['boissons sans alcool', 0.13206598],
#   ['boissons sans alcool', 0.079432842],
#   ['boissons sans alcool', 0.072478918],
#   ['boissons sans alcool', 0.086264229],
#   ['boissons sans alcool', 0.15316255],
#   ['boissons sans alcool', 0.09913837],
#   ['boissons sans alcool', 0.021063881],
#   ['boissons sans alcool', 0.0646810449999999],
#   ['boissons sans alcool', 0.26426993],
#   ['boissons sans alcool', 0.1146654],
#   ['boissons sans alcool', 0.11146884],
#   ['boissons sans alcool', 0.25751296],
#   ['boisson alcoolisées', 0.183838],
#   ['boissons sans alcool', 0.2942368],
#   ['boissons sans alcool', 0.14368608],
#   ['boisson alcoolisées', 0.14270208],
#   ['boissons sans alcool', 0.10571732],
#   ['boisson alcoolisées', 0.11026717],
#   ['boisson alcoolisées', 0.093231189],
#   ['boisson alcoolisées', 0.11689278],
#   ['boisson alcoolisées', 0.13825558],
#   ['boisson alcoolisées', 0.21109516],
#   ['boissons sans alcool', 0.097630551],
#   ['eaux', 0.035859011],
#   ['boisson alcoolisées', 0.1142553499999999],
#   ['boissons sans alcool', 0.58997661],
#   ['boissons sans alcool', 0.1461186699999999],
#   ['boissons sans alcool', 0.082130335],
#   ['boissons sans alcool', 0.12592509],
#   ['boissons sans alcool', 0.14156871],
#   ['boissons sans alcool', 0.051942718],
#   ['boissons sans alcool', 0.60669791],
#   ['boissons sans alcool', 0.083376628],
#   ['boissons sans alcool', 0.088233683],
#   ['boissons sans alcool', 0.096560059],
#   ['boissons sans alcool', 0.025462227],
#   ['boissons sans alcool', 0.1339098],
#   ['boissons sans alcool', 0.10078276],
#   ['boissons sans alcool', 0.060146251],
#   ['boissons sans alcool', 0.19467484],
#   ['boisson alcoolisées', 0.19235828],
#   ['boisson alcoolisées', 0.19353798],
#   ['boissons sans alcool', 0.062999031],
#   ['boisson alcoolisées', 0.21173782],
#   ['boisson alcoolisées', 0.18898055],
#   ['boissons sans alcool', 0.06895598],
#   ['boissons sans alcool', 0.069471586],
#   ['boissons sans alcool', 0.052343884],
#   ['boissons sans alcool', 0.21624926],
#   ['boissons sans alcool', 0.12690721],
#   ['boissons sans alcool', 0.030553053],
#   ['boisson alcoolisées', 0.1129505],
#   ['boisson alcoolisées', 0.17774155],
#   ['boisson alcoolisées', 0.20699059],
#   ['boissons sans alcool', 0.15410196],
#   ['boissons sans alcool', 0.11436633],
#   ['boissons sans alcool', 0.012940545],
#   ['boisson alcoolisées', 0.17057189],
#   ['boisson alcoolisées', 0.17285696],
#   ['boisson alcoolisées', 0.18905958],
#   ['plats composés', 0.31088256],
#   ['plats composés', 0.25389468],
#   ['plats composés', 0.063134881],
#   ['plats composés', 0.060622233],
#   ['feuilletées et autres entrées', 0.57703759],
#   ['soupes', 0.014999437],
#   ['soupes', 0.015283788],
#   ['soupes', 0.014534356],
#   ['plats végétariens', 0.30481652],
#   ['feuilletées et autres entrées', 0.60797659],
#   ['sandwichs', 0.60400325],
#   ['sandwichs', 0.31020567],
#   ['feuilletées et autres entrées', 0.5743370299999999],
#   ['plats composés', 0.30188109],
#   ['plats composés', 0.40092352],
#   ['plats composés', 0.086461256],
#   ['salades composées et crudités', 0.15609557],
#   ['salades composées et crudités', 0.41125763],
#   ['plats composés', 0.5955832600000001],
#   ['plats composés', 0.3147339],
#   ['plats composés', 0.12284477],
#   ['plats composés', 0.4651659199999999],
#   ['plats composés', 0.39528729],
#   ['plats composés', 0.36177966],
#   ['plats composés', 0.12646281],
#   ['pizzas, tartes et crêpes salées', 0.68273655],
#   ['pizzas, tartes et crêpes salées', 0.51184111],
#   ['pizzas, tartes et crêpes salées', 0.36873916],
#   ['pizzas, tartes et crêpes salées', 0.4644064499999999],
#   ['pizzas, tartes et crêpes salées', 0.5240642999999999],
#   ['pizzas, tartes et crêpes salées', 0.2775610899999999],
#   ['pizzas, tartes et crêpes salées', 0.5792542],
#   ['feuilletées et autres entrées', 0.52717881],
#   ['sandwichs', 0.50835729],
#   ['sandwichs', 0.50854427],
#   ['plats composés', 0.4611749699999999],
#   ['plats composés', 0.2147779199999999],
#   ['plats végétariens', 0.27608062],
#   ['pizzas, tartes et crêpes salées', 0.34964328],
#   ['plats composés', 0.14798405],
#   ['feuilletées et autres entrées', 0.53619984],
#   ['feuilletées et autres entrées', 0.35552577],
#   ['feuilletées et autres entrées', 0.4563713199999999],
#   ['feuilletées et autres entrées', 0.63510533],
#   ['pizzas, tartes et crêpes salées', 0.35334658],
#   ['plats composés', 0.28105557],
#   ['sandwichs', 0.43985374],
#   ['plats composés', 0.38167737],
#   ['sandwichs', 0.19456717],
#   ['plats composés', 0.5318544199999999],
#   ['plats végétariens', 0.20996622],
#   ['plats végétariens', 0.2754951699999999],
#   ['plats végétariens', 0.27719081],
#   ['plats composés', 0.3770227399999999],
#   ['plats composés', 0.19033582],
#   ['plats composés', 0.18580579],
#   ['plats composés', 0.18315419],
#   ['plats composés', 0.31735693],
#   ['plats végétariens', 0.29742265],
#   ['plats composés', 0.098073159],
#   ['plats composés', 0.30647885],
#   ['plats composés', 0.54320732],
#   ['plats composés', 0.38902304],
#   ['plats composés', 0.39970849],
#   ['plats composés', 0.5865514],
#   ['plats composés', 0.37646693],
#   ['feuilletées et autres entrées', 0.60098631],
#   ['plats composés', 0.25015199],
#   ['plats végétariens', 0.23948601],
#   ['plats composés', 0.58162732],
#   ['plats composés', 0.2112380999999999],
#   ['sandwichs', 0.31569412],
#   ['plats composés', 0.60064918],
#   ['pizzas, tartes et crêpes salées', 0.6031572199999999],
#   ['plats composés', 0.58438665],
#   ['plats composés', 0.34209571],
#   ['plats composés', 0.34263915],
#   ['plats composés', 0.27889518],
#   ['plats composés', 0.34930143],
#   ['plats composés', 0.29487688],
#   ['plats composés', 0.1669104],
#   ['pizzas, tartes et crêpes salées', 0.25154618],
#   ['pizzas, tartes et crêpes salées', 0.45182353],
#   ['pizzas, tartes et crêpes salées', 0.5335307100000001],
#   ['pizzas, tartes et crêpes salées', 0.33665327],
#   ['pizzas, tartes et crêpes salées', 0.22689262],
#   ['pizzas, tartes et crêpes salées', 0.40451397],
#   ['pizzas, tartes et crêpes salées', 0.34376403],
#   ['pizzas, tartes et crêpes salées', 0.4284266799999999],
#   ['pizzas, tartes et crêpes salées', 0.42372065],
#   ['pizzas, tartes et crêpes salées', 0.44949524],
#   ['pizzas, tartes et crêpes salées', 0.44149942],
#   ['plats composés', 0.16576199],
#   ['plats composés', 0.31847513],
#   ['plats composés', 0.60652178],
#   ['plats composés', 0.6831037],
#   ['pizzas, tartes et crêpes salées', 0.5577787599999999],
#   ['plats composés', 0.21048483],
#   ['plats composés', 0.31239423],
#   ['plats composés', 0.25835766],
#   ['plats composés', 0.33586807],
#   ['plats composés', 0.43747882],
#   ['plats composés', 0.5153952799999999],
#   ['plats composés', 0.51489982],
#   ['feuilletées et autres entrées', 0.3326944599999999],
#   ['salades composées et crudités', 0.37292967],
#   ['salades composées et crudités', 0.12960361],
#   ['salades composées et crudités', 0.39588761],
#   ['salades composées et crudités', 0.22176119],
#   ['salades composées et crudités', 0.4365331999999999],
#   ['salades composées et crudités', 0.57516931],
#   ['salades composées et crudités', 0.33250448],
#   ['sandwichs', 0.32848308],
#   ['sandwichs', 0.31399628],
#   ['sandwichs', 0.5768649800000001],
#   ['sandwichs', 0.63878181],
#   ['sandwichs', 0.37337736],
#   ['sandwichs', 0.44121856],
#   ['sandwichs', 0.28783752],
#   ['sandwichs', 0.40263624],
#   ['sandwichs', 0.4581105],
#   ['sandwichs', 0.28569852],
#   ['sandwichs', 0.38441922],
#   ['sandwichs', 0.53959713],
#   ['plats composés', 0.73152536],
#   ['plats composés', 0.36182434],
#   ['soupes', 0.072774873],
#   ['soupes', 0.1248385499999999],
#   ['soupes', 0.090053989],
#   ['soupes', 0.09758649],
#   ['soupes', 0.062795882],
#   ['soupes', 0.01801179],
#   ['soupes', 0.18412135],
#   ['soupes', 0.14934996],
#   ['soupes', 0.29702344],
#   ['soupes', 0.26227712],
#   ['soupes', 0.11564571],
#   ['soupes', 0.080859114],
#   ['soupes', 0.138159],
#   ['soupes', 0.1033774],
#   ['soupes', 0.1388345399999999],
#   ['soupes', 0.1040531],
#   ['soupes', 0.23864954],
#   ['soupes', 0.20389026],
#   ['soupes', 0.48955574],
#   ['soupes', 0.45485217],
#   ['soupes', 0.14811579],
#   ['soupes', 0.1165787],
#   ['soupes', 0.081792313],
#   ['soupes', 0.1745285899999999],
#   ['soupes', 0.13975506],
#   ['soupes', 0.071351924],
#   ['soupes', 0.10306978],
#   ['soupes', 0.068280389],
#   ['soupes', 0.50279571],
#   ['soupes', 0.50720487],
#   ['soupes', 0.2388486199999999],
#   ['plats composés', 0.44906788],
#   ['salades composées et crudités', 0.27665825],
#   ['salades composées et crudités', 0.1317535299999999],
#   ['pizzas, tartes et crêpes salées', 0.25606932],
#   ['pizzas, tartes et crêpes salées', 0.33170796],
#   ['pizzas, tartes et crêpes salées', 0.39247252],
#   ['pizzas, tartes et crêpes salées', 0.48494777],
#   ['pizzas, tartes et crêpes salées', 0.42077521],
#   ['pizzas, tartes et crêpes salées', 0.56350608],
#   ['pizzas, tartes et crêpes salées', 0.34214555],
#   ['plats composés', 0.30348724],
#   ['plats composés', 0.19023968],
#   ['pizzas, tartes et crêpes salées', 0.46245379],
#   ['sandwichs', 0.19889005],
#   ['plats composés', 0.088937617],
#   ['plats composés', 0.15679996],
#   ['plats composés', 0.5891359199999999],
#   ['sandwichs', 0.26694645],
#   ['fruits', 0.17074512],
#   ['fruits', 0.10049641],
#   ['fruits', 0.17338605],
#   ['fruits', 0.11235591],
#   ['fruits', 0.38921189],
#   ['fruits à coque et graines oléagineuses', 0.7603475399999999],
#   ['fruits', 0.24769773],
#   ['fruits', 0.1504433399999999],
#   ['fruits', 0.24990806],
#   ['fruits', 0.1788394499999999],
#   ['fruits à coque et graines oléagineuses', 0.5872776900000001],
#   ['légumes', 0.18886892],
#   ['légumes', 0.35387889],
#   ['légumes', 0.12914324],
#   ['légumes', 0.19957021],
#   ['légumes', 0.18769747],
#   ['légumes', 0.19643111],
#   ['légumes', 0.29795998],
#   ['légumes', 0.39026335],
#   ['légumes', 0.29264626],
#   ['légumes', 0.070759189],
#   ['légumes', 0.10894185],
#   ['légumes', 0.33159514],
#   ['légumes', 0.21866577],
#   ['légumes', 0.26223191],
#   ['légumes', 0.11293187],
#   ['pommes de terre et autres tubercules', 0.19143359],
#   ['fruits', 0.11888502],
#   ['fruits', 0.55947387],
#   ['légumes', 0.058016574],
#   ['légumes', 0.10830592],
#   ['légumes', 0.055678036],
#   ['légumes', 0.10766449],
#   ['fruits à coque et graines oléagineuses', 0.48218279],
#   ['légumes', 0.093692418],
#   ['légumes', 0.13004784],
#   ['légumes', 0.12323943],
#   ['légumes', 0.13610073],
#   ['légumes', 0.16966704],
#   ['fruits à coque et graines oléagineuses', 0.5807957600000001],
#   ['fruits', 0.65884955],
#   ['fruits', 0.18233194],
#   ['légumes', 0.086921607],
#   ['légumes', 0.1420707],
#   ['légumes', 0.11435665],
#   ['légumes', 0.11290793],
#   ['légumes', 0.091371027],
#   ['légumes', 0.10737264],
#   ['légumes', 0.1361089499999999],
#   ['légumes', 0.13216675],
#   ['fruits', 0.23374772],
#   ['légumes', 0.1308295],
#   ['légumes', 0.069254115],
#   ['légumes', 0.11236704],
#   ['légumes', 0.065009058],
#   ['légumes', 0.0862555729999999],
#   ['fruits', 0.54893393],
#   ['légumes', 0.082851833],
#   ['fruits à coque et graines oléagineuses', 0.36275497],
#   ['fruits à coque et graines oléagineuses', 0.50054009],
#   ['fruits à coque et graines oléagineuses', 0.49656791],
#   ['fruits à coque et graines oléagineuses', 0.4681698],
#   ['légumes', 0.087245337],
#   ['pommes de terre et autres tubercules', 0.21726515],
#   ['légumes', 0.064906277],
#   ['légumes', 0.1317427],
#   ['légumes', 0.084219901],
#   ['légumes', 0.11517949],
#   ['légumes', 0.067048247],
#   ['légumes', 0.11278289],
#   ['légumes', 0.11704113],
#   ['légumes', 0.14740298],
#   ['légumes', 0.078907625],
#   ['légumes', 0.080990062],
#   ['légumes', 0.12244954],
#   ['légumes', 0.075220957],
#   ['légumes', 0.11685771],
#   ['légumes', 0.12461145],
#   ['légumes', 0.1562460899999999],
#   ['légumes', 0.12726126],
#   ['légumes', 0.065149565],
#   ['fruits', 0.14322604],
#   ['fruits', 0.17081395],
#   ['fruits', 0.20149326],
#   ['légumes', 0.0857193429999999],
#   ['fruits', 0.41550527],
#   ['légumes', 0.25900404],
#   ['fruits', 0.078235919],
#   ['fruits', 0.12185375],
#   ['fruits', 0.12376491],
#   ['fruits', 0.1128955],
#   ['fruits', 0.11733174],
#   ['légumes', 0.057580939],
#   ['fruits', 0.36841186],
#   ['fruits', 0.44637766],
#   ['légumes', 0.083475063],
#   ['légumes', 0.1371002],
#   ['légumes', 0.071619717],
#   ['légumes', 0.1171618],
#   ['légumes', 0.12067663],
#   ['légumes', 0.110881],
#   ['fruits à coque et graines oléagineuses', 0.3902179799999999],
#   ['fruits à coque et graines oléagineuses', 0.35331665],
#   ['légumes', 0.12057694],
#   ['légumes', 0.0816052529999999],
#   ['légumes', 0.095279258],
#   ['fruits', 0.35221175],
#   ['fruits', 0.1244643199999999],
#   ['légumes', 0.062847785],
#   ['légumes', 0.11794002],
#   ['légumes', 0.12060346],
#   ['légumes', 0.086711419],
#   ['légumes', 0.045614261],
#   ['légumes', 0.087694697],
#   ['légumes', 0.080888138],
#   ['légumes', 0.09196516],
#   ['légumes', 0.11811104],
#   ['fruits à coque et graines oléagineuses', 0.62036477],
#   ['légumes', 0.16862705],
#   ['légumes', 0.11270856],
#   ['légumineuses', 0.12406383],
#   ['légumineuses', 0.057279032],
#   ['légumineuses', 0.069839348],
#   ['légumineuses', 0.15332993],
#   ['fruits', 0.087689974],
#   ['fruits', 0.21634628],
#   ['fruits', 0.56613579],
#   ['légumes', 0.29148773],
#   ['fruits', 0.12665032],
#   ['fruits', 0.3160788],
#   ['fruits', 0.38450612],
#   ['pommes de terre et autres tubercules', 0.23574926],
#   ['pommes de terre et autres tubercules', 0.18807073],
#   ['pommes de terre et autres tubercules', 0.15983085],
#   ['pommes de terre et autres tubercules', 0.1872291099999999],
#   ['pommes de terre et autres tubercules', 0.17341859],
#   ['fruits', 0.11161584],
#   ['légumes', 0.18197443],
#   ['fruits', 0.13753738],
#   ['fruits', 0.072805715],
#   ['fruits', 0.5182849500000001],
#   ['fruits', 0.27443628],
#   ['fruits', 0.23123566],
#   ['légumes', 0.17688504],
#   ['légumes', 0.12471866],
#   ['légumes', 0.1648699099999999],
#   ['légumineuses', 0.1326182699999999],
#   ['légumineuses', 0.055852634],
#   ['légumineuses', 0.12044629],
#   ['légumes', 0.10116413],
#   ['légumineuses', 0.1361811799999999],
#   ['légumes', 0.18034017],
#   ['légumineuses', 0.13510677],
#   ['légumineuses', 0.13966843],
#   ['légumes', 0.5446476299999999],
#   ['légumes', 0.17581615],
#   ['légumes', 0.1620015],
#   ['légumes', 0.1705047499999999],
#   ['légumes', 0.2081478299999999],
#   ['légumes', 0.15407227],
#   ['pommes de terre et autres tubercules', 0.10537539],
#   ['pommes de terre et autres tubercules', 0.066395212],
#   ['légumes', 0.1138539599999999],
#   ['fruits', 0.1035124499999999],
#   ['fruits', 0.16879149],
#   ['fruits', 0.14668747],
#   ['légumes', 0.088351565],
#   ['légumes', 0.14110744],
#   ['légumes', 0.12600813],
#   ['légumes', 0.11466736],
#   ['légumes', 0.2480420099999999],
#   ['légumes', 0.11870113],
#   ['légumineuses', 0.0594822069999999],
#   ['légumineuses', 0.12919732],
#   ['légumineuses', 0.14123716],
#   ['légumineuses', 0.15324359],
#   ['légumes', 0.10833489],
#   ['légumes', 0.13222913],
#   ['fruits', 0.25123286],
#   ['fruits', 0.15231792],
#   ['fruits', 0.2572604],
#   ['légumes', 0.17887801],
#   ['légumes', 0.20218634],
#   ['légumes', 0.15722083],
#   ['fruits', 0.14736884],
#   ['pommes de terre et autres tubercules', 0.07708359],
#   ['pommes de terre et autres tubercules', 0.1222654599999999],
#   ['fruits à coque et graines oléagineuses', 0.44500815],
#   ['fruits', 0.15098172],
#   ['légumes', 0.1583464],
#   ['fruits', 0.2759608899999999],
#   ['fruits', 0.34235437],
#   ['fruits', 0.33731186],
#   ['fruits', 0.28264034],
#   ['fruits', 0.34902781],
#   ['légumes', 0.0999990489999999],
#   ['fruits', 0.20680502],
#   ['fruits à coque et graines oléagineuses', 0.90993325],
#   ['fruits à coque et graines oléagineuses', 0.6018362100000001],
#   ['fruits à coque et graines oléagineuses', 0.94698476],
#   ['légumes', 0.063478954],
#   ['légumes', 0.10920413],
#   ['légumes', 0.12849974],
#   ['fruits', 0.14783424],
#   ['fruits', 0.66680501],
#   ['fruits', 0.099888397],
#   ['fruits', 0.11047351],
#   ['pommes de terre et autres tubercules', 0.035928205],
#   ['pommes de terre et autres tubercules', 0.080547573],
#   ['pommes de terre et autres tubercules', 0.11670115],
#   ['fruits à coque et graines oléagineuses', 0.56435503],
#   ['fruits', 0.3230584999999999],
#   ['fruits', 0.18128989],
#   ['fruits', 0.2121739899999999],
#   ['légumes', 0.12071682],
#   ['légumes', 0.1566852],
#   ['légumes', 0.16643406],
#   ['légumes', 0.17736716],
#   ['légumes', 0.099743728],
#   ['légumes', 0.14720212],
#   ['légumes', 0.13540264],
#   ['légumes', 0.15557494],
#   ['légumes', 0.1924154],
#   ['légumes', 0.10775027],
#   ['fruits', 0.1064407],
#   ['légumes', 0.096268121],
#   ['légumes', 0.14942252],
#   ['légumes', 0.14177126],
#   ['légumineuses', 0.056508331],
#   ['légumineuses', 0.12288009],
#   ['légumineuses', 0.25055317],
#   ['légumineuses', 0.064081574],
#   ['légumineuses', 0.13991406],
#   ['légumes', 0.1863340899999999],
#   ['légumes', 0.12786703],
#   ['légumes', 0.12258637],
#   ['légumes', 0.16283514],
#   ['fruits', 0.30714095],
#   ['fruits', 0.064749708],
#   ['pommes de terre et autres tubercules', 0.2698077],
#   ['pommes de terre et autres tubercules', 0.41558681],
#   ['pommes de terre et autres tubercules', 0.074902178],
#   ['pommes de terre et autres tubercules', 0.21077889],
#   ['pommes de terre et autres tubercules', 0.33154102],
#   ['pommes de terre et autres tubercules', 0.36688274],
#   ['pommes de terre et autres tubercules', 0.55380317],
#   ['pommes de terre et autres tubercules', 0.04326028],
#   ['pommes de terre et autres tubercules', 0.1231100899999999],
#   ['pommes de terre et autres tubercules', 0.20776007],
#   ['pommes de terre et autres tubercules', 0.076760042],
#   ['pommes de terre et autres tubercules', 0.088322463],
#   ['pommes de terre et autres tubercules', 0.1528796999999999],
#   ['pommes de terre et autres tubercules', 0.1214977999999999],
#   ['pommes de terre et autres tubercules', 0.15793447],
#   ['pommes de terre et autres tubercules', 0.11249718],
#   ['pommes de terre et autres tubercules', 0.053396256],
#   ['pommes de terre et autres tubercules', 0.10891231],
#   ['pommes de terre et autres tubercules', 0.093358548],
#   ['fruits', 0.076175165],
#   ['fruits', 0.10389759],
#   ['fruits', 0.11758428],
#   ['fruits', 0.47096846],
#   ['légumes', 0.13286672],
#   ['légumes', 0.2483247699999999],
#   ['fruits', 0.51852116],
#   ['fruits', 0.5160091],
#   ['fruits', 0.12861913],
#   ['légumes', 0.056485064],
#   ['fruits', 0.0816986869999999],
#   ['fruits', 0.26133073],
#   ['fruits', 0.075658608],
#   ['fruits', 0.19049401],
#   ['pommes de terre et autres tubercules', 0.19022619],
#   ['légumes', 0.11647404],
#   ['fruits', 0.20808625],
#   ['légumes', 0.15893464],
#   ['légumes', 0.12060854],
#   ['légumes', 0.10153115],
#   ['fruits à coque et graines oléagineuses', 0.16463054],
#   ['fruits', 0.1738727199999999],
#   ['fruits', 0.12016768],
#   ['pommes de terre et autres tubercules', 0.1040302],
#   ['pommes de terre et autres tubercules', 0.087163832],
#   ['pommes de terre et autres tubercules', 0.16599104],
#   ['légumes', 0.067171448],
#   ['légumes', 0.091555741],
#   ['légumes', 0.37947959],
#   ['légumes', 0.10282916],
#   ['légumes', 0.59047339],
#   ['légumes', 0.17004208],
#   ['légumes', 0.1477471],
#   ['légumes', 0.16721612],
#   ['légumes', 0.13071537],
#   ['pommes de terre et autres tubercules', 0.059416504],
#   ['pommes de terre et autres tubercules', 0.12277807],
#   ['fruits à coque et graines oléagineuses', 0.4003384299999999],
#   ['glaces', 0.2198397399999999],
#   ['desserts glacés', 0.2198397399999999],
#   ['desserts glacés', 0.24547348],
#   ['sorbets', 0.14631794],
#   ['desserts glacés', 0.31020492],
#   ['sorbets', 0.2174335299999999],
#   ['sorbets', 0.21087747],
#   ['fromages', 0.56226694],
#   ['fromages', 0.55467747],
#   ['fromages', 0.5726676700000001],
#   ['fromages', 0.5140568400000001],
#   ['produits laitiers frais et assimilés', 0.21617512],
#   ['fromages', 0.47384505],
#   ['fromages', 0.47858485],
#   ['fromages', 0.48801722],
#   ['fromages', 0.48520639],
#   ['fromages', 0.5498466],
#   ['fromages', 0.55638425],
#   ['fromages', 0.46899117],
#   ['fromages', 0.46253896],
#   ['fromages', 0.58023706],
#   ['produits laitiers frais et assimilés', 0.33939459],
#   ['produits laitiers frais et assimilés', 0.55031575],
#   ['fromages', 0.58389027],
#   ['fromages', 0.50636509],
#   ['produits laitiers frais et assimilés', 0.323069],
#   ['produits laitiers frais et assimilés', 0.24923736],
#   ['produits laitiers frais et assimilés', 0.2356241],
#   ['crèmes et spécialités à base de crème', 0.1773132899999999],
#   ['produits laitiers frais et assimilés', 0.16483943],
#   ['produits laitiers frais et assimilés', 0.17513803],
#   ['produits laitiers frais et assimilés', 0.24178273],
#   ['produits laitiers frais et assimilés', 0.25208133],
#   ['produits laitiers frais et assimilés', 0.16151603],
#   ['produits laitiers frais et assimilés', 0.12205852],
#   ['produits laitiers frais et assimilés', 0.10330874],
#   ['fromages', 0.55336438],
#   ['fromages', 0.57535793],
#   ['fromages', 0.57800376],
#   ['fromages', 0.46837622],
#   ['produits laitiers frais et assimilés', 0.47744366],
#   ['fromages', 0.69902156],
#   ['produits laitiers frais et assimilés', 0.21517113],
#   ['fromages', 0.4839935],
#   ['fromages', 0.50737582],
#   ['fromages', 0.5167100299999999],
#   ['fromages', 0.5129767599999999],
#   ['fromages', 0.5428209900000001],
#   ['fromages', 0.50174754],
#   ['fromages', 0.4921586699999999],
#   ['fromages', 0.5032995],
#   ['produits laitiers frais et assimilés', 0.16607235],
#   ['produits laitiers frais et assimilés', 0.1864433499999999],
#   ['produits laitiers frais et assimilés', 0.22005549],
#   ['produits laitiers frais et assimilés', 0.17599937],
#   ['fromages', 0.4959452899999999],
#   ['fromages', 0.50712366],
#   ['fromages', 0.47234065],
#   ['fromages', 0.50863154],
#   ['fromages', 0.60449872],
#   ['fromages', 0.66728113],
#   ['produits laitiers frais et assimilés', 0.1833877],
#   ['produits laitiers frais et assimilés', 0.23329664],
#   ['produits laitiers frais et assimilés', 0.19255465],
#   ['fromages', 0.46212319],
#   ['fromages', 0.46652019],
#   ['fromages', 0.47741036],
#   ['produits laitiers frais et assimilés', 0.63355534],
#   ['produits laitiers frais et assimilés', 0.25904115],
#   ['produits laitiers frais et assimilés', 0.27547884],
#   ['produits laitiers frais et assimilés', 0.16352058],
#   ['produits laitiers frais et assimilés', 0.18188683],
#   ['fromages', 0.48004045],
#   ['fromages', 0.55531186],
#   ['fromages', 0.57150082],
#   ['fromages', 0.5807905],
#   ['fromages', 0.57459387],
#   ['produits laitiers frais et assimilés', 0.23782742],
#   ['laits', 0.23057785],
#   ['laits', 0.25736379],
#   ['laits', 0.20474611],
#   ['laits', 0.12136178],
#   ['laits', 0.10998779],
#   ['produits laitiers frais et assimilés', 0.1690294399999999],
#   ['laits', 0.13790575],
#   ['produits laitiers frais et assimilés', 0.1675925499999999],
#   ['produits laitiers frais et assimilés', 0.1524854699999999],
#   ['produits laitiers frais et assimilés', 0.1825948],
#   ['produits laitiers frais et assimilés', 0.27344677],
#   ['produits laitiers frais et assimilés', 0.24319805],
#   ['produits laitiers frais et assimilés', 0.16196083],
#   ['produits laitiers frais et assimilés', 0.2281628799999999],
#   ['fromages', 0.46558584],
#   ['produits laitiers frais et assimilés', 0.32179502],
#   ['fromages', 0.49514017],
#   ['fromages', 0.4972796899999999],
#   ['fromages', 0.50611153],
#   ['produits laitiers frais et assimilés', 0.13408819],
#   ['fromages', 0.58115836],
#   ['fromages', 0.56350108],
#   ['fromages', 0.5883395100000001],
#   ['fromages', 0.53837211],
#   ['fromages', 0.47946118],
#   ['fromages', 0.55358186],
#   ['produits laitiers frais et assimilés', 0.6917782600000001],
#   ['produits laitiers frais et assimilés', 0.36116558],
#   ['produits laitiers frais et assimilés', 0.2919549],
#   ['fromages', 0.4339906],
#   ['fromages', 0.49324822],
#   ['fromages', 0.45665574],
#   ['produits laitiers frais et assimilés', 0.23787706],
#   ['produits laitiers frais et assimilés', 0.2178597],
#   ['fromages', 0.57478522],
#   ['fromages', 0.49886867],
#   ['produits laitiers frais et assimilés', 0.30930408],
#   ['fromages', 0.55183419],
#   ['produits laitiers frais et assimilés', 0.28577745],
#   ['fromages', 0.45070746],
#   ['fromages', 0.44146274],
#   ['fromages', 0.50885278],
#   ['fromages', 0.5335662800000001],
#   ['fromages', 0.53240512],
#   ['fromages', 0.5774568099999999],
#   ['fromages', 0.42775139],
#   ['fromages', 0.30793915],
#   ['fromages', 0.53370947],
#   ['fromages', 0.53184931],
#   ['fromages', 0.52512851],
#   ['fromages', 0.52874515],
#   ['produits laitiers frais et assimilés', 0.29345753],
#   ['produits laitiers frais et assimilés', 0.2196269],
#   ['produits laitiers frais et assimilés', 0.24987562],
#   ['produits laitiers frais et assimilés', 0.2429906399999999],
#   ['produits laitiers frais et assimilés', 0.15902364],
#   ['produits laitiers frais et assimilés', 0.16552284],
#   ['produits laitiers frais et assimilés', 0.25652759],
#   ['produits laitiers frais et assimilés', 0.39203084],
#   ['produits laitiers frais et assimilés', 0.22306491],
#   ['produits laitiers frais et assimilés', 0.16182397],
#   ['beurres', 0.59382404],
#   ['beurres', 0.67537667],
#   ['beurres', 0.6779845],
#   ['autres matières grasses', 0.21117884],
#   ['huiles et graisses végétales', 0.36954531],
#   ['huiles et graisses végétales', 0.40730957],
#   ['huiles et graisses végétales', 0.33071262],
#   ['huiles et graisses végétales', 0.6608056],
#   ['huiles et graisses végétales', 0.4780442099999999],
#   ['huiles et graisses végétales', 0.4645357699999999],
#   ['huiles et graisses végétales', 0.42616987],
#   ['huiles et graisses végétales', 0.17988682],
#   ['huiles et graisses végétales', 0.3675406899999999],
#   ['huiles et graisses végétales', 0.3956131699999999],
#   ['huiles et graisses végétales', 0.59092455],
#   ['huiles et graisses végétales', 0.3826330599999999],
#   ['autres matières grasses', 0.2060567],
#   ['beurres', 0.44487444],
#   ['beurres', 0.4934383899999999],
#   ['margarines', 0.33573054],
#   ['margarines', 0.29353404],
#   ['huiles et graisses végétales', 0.39703826],
#   ['margarines', 0.21260035],
#   ['margarines', 0.29149888],
#   ['margarines', 0.2795141599999999],
#   ['margarines', 0.27978115],
#   ['margarines', 0.29289599],
#   ['margarines', 0.2809783899999999],
#   ['margarines', 0.30275164],
#   ['margarines', 0.32998889],
#   ['margarines', 0.3665766199999999],
#   ['margarines', 0.22305725],
#   ['margarines', 0.23750199],
#   ['margarines', 0.22620459],
#   ['margarines', 0.34622805],
#   ['pâtes, riz et céréales', 0.14016608],
#   ['farines et pâtes à tarte', 0.1681118],
#   ['pâtes, riz et céréales', 0.23259643],
#   ['gâteaux et pâtisseries', 0.11571428],
#   ['pains et viennoiseries', 0.1335530999999999],
#   ['gâteaux et pâtisseries', 0.44904233],
#   ['céréales de petit-déjeuner et biscuits', 0.30698672],
#   ['céréales de petit-déjeuner et biscuits', 0.31924367],
#   ['céréales de petit-déjeuner et biscuits', 0.47217271],
#   ['céréales de petit-déjeuner et biscuits', 0.49978588],
#   ['gâteaux et pâtisseries', 0.22932974],
#   ['gâteaux et pâtisseries', 0.24977559],
#   ['gâteaux et pâtisseries', 0.40155622],
#   ['gâteaux et pâtisseries', 0.21828622],
#   ['pains et viennoiseries', 0.12778036],
#   ['céréales de petit-déjeuner et biscuits', 0.2193900899999999],
#   ['céréales de petit-déjeuner et biscuits', 0.34482349],
#   ['gâteaux et pâtisseries', 0.474877],
#   ['céréales de petit-déjeuner et biscuits', 0.31569195],
#   ['céréales de petit-déjeuner et biscuits', 0.3693335499999999],
#   ['céréales de petit-déjeuner et biscuits', 0.4599157599999999],
#   ['céréales de petit-déjeuner et biscuits', 0.25263582],
#   ['céréales de petit-déjeuner et biscuits', 0.5154371999999999],
#   ['céréales de petit-déjeuner et biscuits', 0.48752893],
#   ['céréales de petit-déjeuner et biscuits', 0.30946805],
#   ['céréales de petit-déjeuner et biscuits', 0.41693712],
#   ['céréales de petit-déjeuner et biscuits', 0.38754546],
#   ['céréales de petit-déjeuner et biscuits', 0.17428117],
#   ['pâtes, riz et céréales', 0.061709498],
#   ['pâtes, riz et céréales', 0.074831241],
#   ['pâtes, riz et céréales', 0.10387694],
#   ['pains et viennoiseries', 0.21470569],
#   ['pâtes, riz et céréales', 0.063134946],
#   ['pains et viennoiseries', 0.31310717],
#   ['pains et viennoiseries', 0.4471077],
#   ['pains et viennoiseries', 0.3103332],
#   ['pains et viennoiseries', 0.38278974],
#   ['gâteaux et pâtisseries', 0.6507024299999999],
#   ['gâteaux et pâtisseries', 0.5269709499999999],
#   ['céréales de petit-déjeuner et biscuits', 0.47256509],
#   ['gâteaux et pâtisseries', 0.3126626999999999],
#   ['gâteaux et pâtisseries', 0.23643074],
#   ['céréales de petit-déjeuner et biscuits', 0.61362431],
#   ['gâteaux et pâtisseries', 0.2524981599999999],
#   ['pains et viennoiseries', 0.23318043],
#   ['céréales de petit-déjeuner et biscuits', 0.35297858],
#   ['céréales de petit-déjeuner et biscuits', 0.21726477],
#   ['gâteaux et pâtisseries', 0.29098813],
#   ['gâteaux et pâtisseries', 0.2377281799999999],
#   ['pains et viennoiseries', 0.2820775],
#   ['céréales de petit-déjeuner et biscuits', 0.66996182],
#   ['céréales de petit-déjeuner et biscuits', 0.37132882],
#   ['gâteaux et pâtisseries', 0.44712912],
#   ['pains et viennoiseries', 0.37808998],
#   ['pâtes, riz et céréales', 0.2299527499999999],
#   ['pâtes, riz et céréales', 0.1028775399999999],
#   ['gâteaux et pâtisseries', 0.2141644899999999],
#   ['gâteaux et pâtisseries', 0.3690157],
#   ['gâteaux et pâtisseries', 0.23696844],
#   ['gâteaux et pâtisseries', 0.22346006],
#   ['pains et viennoiseries', 0.26403923],
#   ['pains et viennoiseries', 0.3390033],
#   ['pains et viennoiseries', 0.20648782],
#   ['pains et viennoiseries', 0.4436778899999999],
#   ['gâteaux et pâtisseries', 0.21953473],
#   ['gâteaux et pâtisseries', 0.30907901],
#   ['gâteaux et pâtisseries', 0.45234435],
#   ['gâteaux et pâtisseries', 0.57176369],
#   ['farines et pâtes à tarte', 0.098772307],
#   ['farines et pâtes à tarte', 0.098761749],
#   ['farines et pâtes à tarte', 0.098794759],
#   ['farines et pâtes à tarte', 0.13110098],
#   ['farines et pâtes à tarte', 0.15098129],
#   ['farines et pâtes à tarte', 0.13666047],
#   ['farines et pâtes à tarte', 1.1459199999999998],
#   ['farines et pâtes à tarte', 0.15376344],
#   ['farines et pâtes à tarte', 0.10571839],
#   ['farines et pâtes à tarte', 0.1806219],
#   ['farines et pâtes à tarte', 0.13826364],
#   ['gâteaux et pâtisseries', 0.23169875],
#   ['gâteaux et pâtisseries', 0.29873593],
#   ['pains et viennoiseries', 0.39551242],
#   ['gâteaux et pâtisseries', 0.1146135599999999],
#   ['gâteaux et pâtisseries', 0.47507809],
#   ['gâteaux et pâtisseries', 0.59531277],
#   ['gâteaux et pâtisseries', 0.25107946],
#   ['gâteaux et pâtisseries', 0.29009869],
#   ['gâteaux et pâtisseries', 0.5255633000000001],
#   ['gâteaux et pâtisseries', 0.25222575],
#   ['gâteaux et pâtisseries', 0.37905946],
#   ['gâteaux et pâtisseries', 0.60153009],
#   ['gâteaux et pâtisseries', 0.31470652],
#   ['gâteaux et pâtisseries', 0.50274315],
#   ['gâteaux et pâtisseries', 0.33808467],
#   ['gâteaux et pâtisseries', 0.31470525],
#   ['gâteaux et pâtisseries', 0.31454391],
#   ['gâteaux et pâtisseries', 0.35238069],
#   ['gâteaux et pâtisseries', 0.28944619],
#   ['gâteaux et pâtisseries', 0.40438101],
#   ['gâteaux et pâtisseries', 0.29992885],
#   ['céréales de petit-déjeuner et biscuits', 0.30714932],
#   ['pâtes, riz et céréales', 0.093432454],
#   ['pâtes, riz et céréales', 0.12046376],
#   ['pains et viennoiseries', 0.1543319],
#   ['farines et pâtes à tarte', 0.14528612],
#   ['gâteaux et pâtisseries', 0.1619503299999999],
#   ['gâteaux et pâtisseries', 0.5299960199999999],
#   ['céréales de petit-déjeuner et biscuits', 0.41017763],
#   ['gâteaux et pâtisseries', 0.5737486700000001],
#   ['gâteaux et pâtisseries', 0.27715321],
#   ['gâteaux et pâtisseries', 0.4267796199999999],
#   ['pâtes, riz et céréales', 0.12224862],
#   ['pâtes, riz et céréales', 0.1028142],
#   ['céréales de petit-déjeuner et biscuits', 0.31938193],
#   ['pâtes, riz et céréales', 0.1378297],
#   ['pâtes, riz et céréales', 0.0621007889999999],
#   ['gâteaux et pâtisseries', 0.23892082],
#   ['céréales de petit-déjeuner et biscuits', 0.26388947],
#   ['céréales de petit-déjeuner et biscuits', 0.26397846],
#   ['pains et viennoiseries', 0.11748159],
#   ['pains et viennoiseries', 0.22810921],
#   ['gâteaux et pâtisseries', 0.35136729],
#   ['pâtes, riz et céréales', 0.2579192899999999],
#   ['pâtes, riz et céréales', 0.20425219],
#   ['pâtes, riz et céréales', 0.12714977],
#   ['pâtes, riz et céréales', 0.12050533],
#   ['pains et viennoiseries', 0.38747417],
#   ['pains et viennoiseries', 0.28055886],
#   ['pains et viennoiseries', 0.28782702],
#   ['pains et viennoiseries', 0.09237119],
#   ['pains et viennoiseries', 0.2788219],
#   ['pains et viennoiseries', 0.10040847],
#   ['pains et viennoiseries', 0.2176056999999999],
#   ['pains et viennoiseries', 0.10067584],
#   ['pains et viennoiseries', 0.21655878],
#   ['pains et viennoiseries', 0.19157953],
#   ['pains et viennoiseries', 0.18843288],
#   ['pains et viennoiseries', 0.15130702],
#   ['pains et viennoiseries', 0.10362007],
#   ['gâteaux et pâtisseries', 0.23061747],
#   ['pains et viennoiseries', 0.20430183],
#   ['pains et viennoiseries', 0.17617593],
#   ['pains et viennoiseries', 0.12191397],
#   ['pains et viennoiseries', 0.10965702],
#   ['pains et viennoiseries', 0.10161974],
#   ['pains et viennoiseries', 0.16026935],
#   ['pains et viennoiseries', 0.1411717599999999],
#   ['pains et viennoiseries', 0.09942153],
#   ['pains et viennoiseries', 0.21062532],
#   ['pains et viennoiseries', 0.098207729],
#   ['pains et viennoiseries', 0.18889495],
#   ['pains et viennoiseries', 0.10900353],
#   ['pains et viennoiseries', 0.2149474099999999],
#   ['farines et pâtes à tarte', 0.18368603],
#   ['farines et pâtes à tarte', 0.36435356],
#   ['farines et pâtes à tarte', 0.36422533],
#   ['farines et pâtes à tarte', 0.39136905],
#   ['farines et pâtes à tarte', 0.39004497],
#   ['farines et pâtes à tarte', 0.4018700799999999],
#   ['farines et pâtes à tarte', 0.26209727],
#   ['farines et pâtes à tarte', 0.38507549],
#   ['farines et pâtes à tarte', 0.38402999],
#   ['pâtes, riz et céréales', 0.23004197],
#   ['pâtes, riz et céréales', 0.26391586],
#   ['pâtes, riz et céréales', 0.27598916],
#   ['pâtes, riz et céréales', 0.1347042199999999],
#   ['pâtes, riz et céréales', 0.26177113],
#   ['pâtes, riz et céréales', 0.1346346699999999],
#   ['pâtes, riz et céréales', 0.25707328],
#   ['pâtes, riz et céréales', 0.23523808],
#   ['pâtes, riz et céréales', 0.1166663499999999],
#   ['céréales de petit-déjeuner et biscuits', 0.18740252],
#   ['céréales de petit-déjeuner et biscuits', 0.1691862],
#   ['céréales de petit-déjeuner et biscuits', 0.23403871],
#   ['gâteaux et pâtisseries', 0.42950113],
#   ['pâtes, riz et céréales', 1.1966895999999998],
#   ...],
#  3: [['feuilletées et autres entrées', 1.3650104],
#   ['plats composés', 2.3588962],
#   ['plats composés', 1.4513234],
#   ['plats composés', 1.4049352],
#   ['plats composés', 1.4093466],
#   ['plats composés', 1.458966],
#   ['plats composés', 1.5499276],
#   ['plats composés', 1.6259404],
#   ['plats composés', 1.4675417],
#   ['salades composées et crudités', 2.7235316000000003],
#   ['soupes', 1.4701742],
#   ['soupes', 1.4356884],
#   ['poissons crus', 1.5667808],
#   ['poissons crus', 1.4861231],
#   ['poissons crus', 1.8887829],
#   ['poissons cuits', 2.33483],
#   ['produits à base de poissons et produits de la mer', 2.3202734],
#   ['mollusques et crustacés cuits', 1.6128597],
#   ['mollusques et crustacés cuits', 5.69437],
#   ['poissons cuits', 1.5365283],
#   ['poissons cuits', 2.3173587],
#   ['poissons cuits', 1.8861137],
#   ['mollusques et crustacés cuits', 5.7793728],
#   ['mollusques et crustacés crus', 3.6272486],
#   ['produits à base de poissons et produits de la mer', 2.3377455],
#   ['poissons cuits', 1.4173185],
#   ['produits à base de poissons et produits de la mer', 1.4584465],
#   ['produits à base de poissons et produits de la mer', 1.4617315],
#   ['produits à base de poissons et produits de la mer', 1.3720007],
#   ['poissons crus', 1.5394438],
#   ['poissons cuits', 1.519057],
#   ['produits à base de poissons et produits de la mer', 1.3313476],
#   ['produits à base de poissons et produits de la mer', 1.6328881],
#   ['produits à base de poissons et produits de la mer', 1.8460746]],
#  4: [['boissons sans alcool', 4.4554581],
#   ['boissons sans alcool', 4.339617700000001],
#   ['viandes cuites', 5.8133515],
#   ['viandes crues', 4.5769943],
#   ['viandes cuites', 5.7963682],
#   ['viandes crues', 4.5756975],
#   ['viandes cuites', 5.7947254],
#   ['viandes cuites', 4.6537464],
#   ['viandes cuites', 4.1426872],
#   ['viandes cuites', 4.1369706],
#   ['viandes cuites', 4.0779579],
#   ['autres produits à base de viande', 5.7993625],
#   ['viandes cuites', 5.7963667],
#   ['charcuteries', 4.0398115],
#   ['charcuteries', 4.0712435000000005],
#   ['viandes cuites', 4.133198200000001]]}

# %%
moyennes_clusters
# Out:
# {0: 1.1867991587671236,
#  1: 2.703827284090909,
#  2: 0.28013220762455215,
#  3: 1.990822867647059,
#  4: 4.7627223249999995}

# %%
# Supposons que 'moyennes_clusters' est votre dictionnaire contenant les moyennes des scores EF par cluster
cluster_labels = list(clusters.keys())
aliments_par_cluster = [len(clusters[cluster]) for cluster in cluster_labels]
scores_moyens_ef = [moyennes_clusters[cluster] for cluster in cluster_labels]

fig, ax1 = plt.subplots(figsize=(10, 6))

# Créer le diagramme à barres pour le nombre d'aliments par cluster
ax1.bar(
    cluster_labels, aliments_par_cluster, color="skyblue", label="Nombre d'Aliments"
)
ax1.set_xlabel("Numéro du Cluster")
ax1.set_ylabel("Nombre d'Aliments", color="skyblue")
ax1.tick_params(axis="y", labelcolor="skyblue")
ax1.set_title("Nombre d'Aliments et Score EF Moyen par Cluster")

# Créer un second axe pour les scores EF moyens
ax2 = ax1.twinx()
ax2.plot(
    cluster_labels, scores_moyens_ef, color="red", label="Score EF Moyen", marker="o"
)
ax2.set_ylabel("Score EF Moyen", color="red")
ax2.tick_params(axis="y", labelcolor="red")

# Ajouter une légende
fig.legend(loc="upper left", bbox_to_anchor=(0.9, 0.9))

plt.xticks(cluster_labels)
plt.show()

# %%
# Find the key with the maximum value
key_max_value = max(moyennes_clusters, key=moyennes_clusters.get)

print(key_max_value)  # Outputs: 'b'
# Out:
# 4

# %%
clusters_uniques = {}
for cluster in clusters.keys():
    # Sélectionner les aliments uniques pour chaque cluster
    clusters_uniques[cluster] = df_synt[df_synt["cluster"] == cluster][
        "Sous-groupe d'aliment"
    ].unique()

# Afficher les aliments uniques pour chaque cluster
clusters_uniques[key_max_value]
# Out:
# array(['boissons sans alcool', 'viandes cuites', 'viandes crues',
#        'autres produits à base de viande', 'charcuteries'], dtype=object)

# %%
from collections import defaultdict

# Supposons que 'clusters' est votre dictionnaire contenant les aliments et leurs scores EF par cluster
# et que le cinquième cluster est indexé par 4 (si vous commencez à compter à partir de 0)
aliments_scores_cluster_5 = clusters[
    key_max_value
]  # Remplacez '4' par l'index approprié si nécessaire

# Créer un dictionnaire pour cumuler les scores EF et compter les occurrences des aliments de même nom
cumul_scores_ef = defaultdict(
    lambda: [0, 0]
)  # Le premier élément est la somme des scores, le second est le compteur
for aliment, score_ef in aliments_scores_cluster_5:
    cumul_scores_ef[aliment][0] += score_ef
    cumul_scores_ef[aliment][1] += 1

# Calculer la moyenne des scores EF pour les aliments de même nom
moyennes_scores_ef = {
    aliment: total_score / count
    for aliment, (total_score, count) in cumul_scores_ef.items()
}

# Convertir le dictionnaire des moyennes en une liste triée pour la visualisation
aliments_moyennes = sorted(
    moyennes_scores_ef.items(), key=lambda item: item[1], reverse=True
)

# Extraire les noms des aliments et les moyennes des scores EF
noms_aliments_moyennes = [aliment for aliment, _ in aliments_moyennes]
moyennes_ef = [moyenne for _, moyenne in aliments_moyennes]

plt.figure(figsize=(12, 8))
bars = plt.barh(noms_aliments_moyennes, moyennes_ef, color="green")
plt.xlabel("Moyenne du Score EF")
plt.title(
    f"Moyenne de l'Impact Environnemental des Aliments du cluster {key_max_value}"
)
plt.gca().invert_yaxis()  # Inverser l'axe y pour afficher le score le plus élevé en haut

# Ajouter des annotations sur chaque barre
for bar in bars:
    plt.text(
        bar.get_width(),
        bar.get_y() + bar.get_height() / 2,
        f"{bar.get_width():.2f}",
        va="center",
        ha="left",
        color="black",
    )

plt.tight_layout()
plt.show()

# %%
df_cluster_5 = df_synt[df_synt["cluster"] == key_max_value]
df_etape_5 = df_etape.iloc[:, 6:-3]

# Save "Code CIQUAL" column in a variable
code_ciqual = df_etape["Code CIQUAL"]

# Insert "Code CIQUAL" column at position 0
df_etape_5.insert(0, "Code CIQUAL", code_ciqual)

# Perform the join
df_jointure = pd.merge(df_cluster_5, df_etape_5, on="Code CIQUAL")


print(df_cluster_5.shape)


print(df_jointure.shape)
# Out:
# (32, 33)
# (32, 140)

# %%
df_jointure.head()
# Out:
#   Code AGB  Code CIQUAL         Groupe d'aliment Sous-groupe d'aliment  \
# 0    18069        18069                 boissons  boissons sans alcool
# 1    18005        18005                 boissons  boissons sans alcool
# 2    21508        21508  viandes, œufs, poissons        viandes cuites
# 3    21514        21514  viandes, œufs, poissons         viandes crues
# 4    21516        21516  viandes, œufs, poissons         viandes crues
#
#            Nom du Produit en Français  \
# 0     Café, décaféiné, poudre soluble
# 1                Café, poudre soluble
# 2  Agneau, collier, braisé ou bouilli
# 3                Agneau, collier, cru
# 4            Agneau, côte filet, crue
#
#                                             LCI Name  code saison  code avion  \
# 0  Decaffeinated coffee, powder, instant, non reh...            2       False
# 1            Coffee, powder, instant, non rehydrated            2       False
# 2                      Lamb, neck, braised or boiled            2       False
# 3                                    Lamb, neck, raw            2       False
# 4                             Lamb, chop fillet, raw            2       False
#
#         Livraison Matériau d'emballage  ...  \
# 0  Ambiant (long)               Carton  ...
# 1  Ambiant (long)               Carton  ...
# 2           Glacé                   PS  ...
# 3           Glacé                   PS  ...
# 4           Glacé                   PS  ...
#
#   Épuisement des ressources minéraux - Transformation  \
# 0                                       1.492758e-05
# 1                                       1.007542e-05
# 2                                       3.148007e-07
# 3                                       2.491977e-07
# 4                                       2.491977e-07
#
#    Épuisement des ressources minéraux - Emballage  \
# 0                                    4.659462e-07
# 1                                    4.659462e-07
# 2                                    5.337783e-08
# 3                                    4.225414e-08
# 4                                    4.225414e-08
#
#    Épuisement des ressources minéraux - Transport  \
# 0                                        0.000001
# 1                                        0.000001
# 2                                        0.000001
# 3                                        0.000001
# 4                                        0.000001
#
#    Épuisement des ressources minéraux - Supermarché et distribution  \
# 0                                       4.396778e-07
# 1                                       4.396778e-07
# 2                                       1.443461e-06
# 3                                       1.142650e-06
# 4                                       1.142650e-06
#
#    Épuisement des ressources minéraux - Consommation  DQR - Global  DQR - P  \
# 0                                       0.000000e+00          3.49     3.72
# 1                                       0.000000e+00          3.49     3.72
# 2                                       3.826202e-06          2.65     3.66
# 3                                       3.454751e-07          2.63     3.69
# 4                                       3.454751e-07          2.63     3.69
#
#    DQR - TiR  DQR - GR  DQR - TeR
# 0       3.41      2.29       4.54
# 1       3.41      2.29       4.54
# 2       1.28      2.04       3.60
# 3       1.21      2.01       3.62
# 4       1.21      2.01       3.62
#
# [5 rows x 140 columns]

# %%
df_jointure.columns[12:29]
# Out:
# Index(['Score unique EF', 'Changement climatique',
#        'Appauvrissement de la couche d'ozone', 'Rayonnements ionisants',
#        'Formation photochimique d'ozone', 'Particules fines',
#        'Effets toxicologiques sur la santé humaine   substances non-cancérogènes',
#        'Effets toxicologiques sur la santé humaine   substances cancérogènes',
#        'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces',
#        'Eutrophisation marine', 'Eutrophisation terrestre',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce',
#        'Utilisation du sol', 'Épuisement des ressources eau',
#        'Épuisement des ressources énergétiques',
#        'Épuisement des ressources minéraux'],
#       dtype='object')

# %%
from statsmodels.stats.multicomp import MultiComparison

scaler = MinMaxScaler()
df_join_norm = df_jointure.copy()
df_join_norm = scaler.fit_transform(df_join_norm.iloc[:, 12:29])
df_join_norm = pd.DataFrame(df_join_norm, columns=df_jointure.columns[12:29])
df_join_norm["Sous-groupe d'aliment"] = df_jointure["Sous-groupe d'aliment"]

mc = MultiComparison(
    df_join_norm["Changement climatique"], df_join_norm["Sous-groupe d'aliment"]
)

result = mc.tukeyhsd(alpha=0.05)

print(result.summary())
# Out:
#                     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================================================
#              group1                     group2        meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------------------------
# autres produits à base de viande boissons sans alcool  -0.9557  0.001 -1.5765 -0.335   True
# autres produits à base de viande         charcuteries  -0.5063  0.151 -1.1271 0.1144  False
# autres produits à base de viande        viandes crues  -0.4356 0.1556 -0.9731  0.102  False
# autres produits à base de viande       viandes cuites  -0.1793 0.8499 -0.6993 0.3407  False
#             boissons sans alcool         charcuteries   0.4494 0.1007 -0.0575 0.9562  False
#             boissons sans alcool        viandes crues   0.5202 0.0063  0.1195 0.9209   True
#             boissons sans alcool       viandes cuites   0.7765    0.0  0.3997 1.1532   True
#                     charcuteries        viandes crues   0.0708  0.985 -0.3299 0.4715  False
#                     charcuteries       viandes cuites   0.3271 0.1123 -0.0497 0.7039  False
#                    viandes crues       viandes cuites   0.2563 0.0129  0.0427 0.4699   True
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ```markdown
# D'après le résumé de l'analyse Tukey HSD que vous avez fourni, voici les produits à impact élevé sur le changement climatique :
#
# 1. **Boissons sans alcool vs Autres produits à base de viande** : Les boissons sans alcool ont un impact significativement plus faible sur le changement climatique que les autres produits à base de viande, avec une différence moyenne de -22.9834 et une valeur p de 0.001. Cela suggère que les autres produits à base de viande pourraient être une cible prioritaire pour réduire l'impact environnemental.
#
# 2. **Boissons sans alcool vs Viandes crues** : Les boissons sans alcool ont également un impact significativement plus faible que les viandes crues, avec une différence moyenne de 12.5092 et une valeur p de 0.0063. Les viandes crues pourraient donc aussi être considérées comme ayant un impact élevé.
#
# 3. **Boissons sans alcool vs Viandes cuites** : De même, les boissons sans alcool ont un impact significativement plus faible que les viandes cuites, avec une différence moyenne de 18.6723 et une valeur p de 0.0. Les viandes cuites sont donc un autre groupe à impact élevé.
#
# 4. **Viandes crues vs Viandes cuites** : Il y a une différence significative entre les viandes crues et les viandes cuites, avec une différence moyenne de 6.1632 et une valeur p de 0.0129. Cela indique que les viandes cuites ont un impact plus élevé que les viandes crues.
#
# Les autres comparaisons n'ont pas montré de différences significatives, ce qui signifie que l'on ne peut pas conclure à un impact élevé basé sur ces données.
#
# Pour guider les décisions en matière de politique alimentaire ou de recommandations de consommation, on pourrait envisager de promouvoir une consommation réduite des produits à base de viande, en particulier des viandes cuites, et d'encourager des alternatives avec un impact moindre, comme les boissons sans alcool. De plus, des efforts pourraient être faits pour améliorer les pratiques de production dans le secteur de la viande afin de réduire son empreinte carbone.

# %%
# Calculer la moyenne du score EF pour chaque catégorie
moyennes_par_categorie = df_join_norm.groupby("Sous-groupe d'aliment")[
    "Changement climatique"
].mean()

# Préparer les données pour le diagramme en camembert
labels = moyennes_par_categorie.index
sizes = moyennes_par_categorie.values
colors = plt.cm.Paired(range(len(labels)))  # Générer des couleurs pour chaque catégorie

# Créer le diagramme en camembert
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%", startangle=140)
plt.axis("equal")  # Assurer que le camembert est un cercle
plt.title("Pourcentage d'Impact sur le Changement Climatique par Catégorie d'Aliments")
plt.show()

# %%
# Création du diagramme en barresplt.figure(figsize=(10, 6))
moyennes_par_categorie.plot(kind="bar", color="skyblue")

# Ajouter des titres et des étiquettes
plt.title("Moyenne de Changement Climatique par Sous-groupe d'Aliments")
plt.xlabel("Sous-groupe d'Aliments")
plt.ylabel("Moyenne de Changement Climatique")
plt.xticks(
    rotation=90, ha="right"
)  # Rotation des étiquettes pour une meilleure lisibilité

plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
plt.show()

# %%
df_subset = df_join_norm.iloc[:, 1:-1]
# Matrice de corrélation pour le sous-ensemble
correlation_matrix_subset = df_subset.corr()

# Heatmap des corrélations pour le sous-ensemble
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix_subset, annot=True, cmap="coolwarm")
plt.title("Matrice de corrélation pour le sous-ensemble de colonnes")
plt.show()

# %%
from sklearn.decomposition import PCA

# Supposons que df_join_norm est votre DataFrame et contient les indicateurs d'impact environnemental
# Sélectionner les colonnes d'impact environnemental pour l'ACP
colonnes_impact = df_join_norm.columns[1:-1]

# Préparer les données pour l'ACP
X = df_join_norm[colonnes_impact]

# Initialiser l'ACP
pca = PCA()  # Utiliser tous les composantes pour l'exemple
X_r = pca.fit_transform(X)

summary_table = pd.DataFrame(
    columns=[
        "Dimension",
        "Explained Variance",
        "Explained Variance Ratio",
        "Cumulative Explained Variance Ratio",
    ]
)

# Créer une liste pour stocker les lignes du tableau récapitulatif
rows = []

# Calculer les proportions cumulatives de variance expliquée
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Remplir la liste avec les informations sur chaque dimension
for i in range(len(pca.explained_variance_)):
    rows.append(
        {
            "Dimension": i + 1,
            "Explained Variance": pca.explained_variance_[i],
            "Explained Variance Ratio": pca.explained_variance_ratio_[i],
            "Cumulative Explained Variance Ratio": cumulative_variance_ratio[i],
        }
    )

# Créer le DataFrame récapitulatif en concaténant les lignes
summary_table = pd.concat([pd.DataFrame([row]) for row in rows], ignore_index=True)

summary_table
# Out:
#     Dimension  Explained Variance  Explained Variance Ratio  \
# 0           1        6.778787e-01              5.129386e-01
# 1           2        5.156703e-01              3.901984e-01
# 2           3        1.199902e-01              9.079441e-02
# 3           4        7.213914e-03              5.458639e-03
# 4           5        7.539446e-04              5.704962e-04
# 5           6        3.447021e-05              2.608299e-05
# 6           7        1.594424e-05              1.206472e-05
# 7           8        9.772846e-07              7.394936e-07
# 8           9        6.475944e-07              4.900230e-07
# 9          10        6.974055e-08              5.277141e-08
# 10         11        2.663053e-08              2.015084e-08
# 11         12        1.325795e-08              1.003205e-08
# 12         13        2.990827e-09              2.263105e-09
# 13         14        8.010290e-17              6.061242e-17
# 14         15        1.474991e-17              1.116099e-17
# 15         16        3.269859e-34              2.474243e-34
#
#     Cumulative Explained Variance Ratio
# 0                              0.512939
# 1                              0.903137
# 2                              0.993931
# 3                              0.999390
# 4                              0.999961
# 5                              0.999987
# 6                              0.999999
# 7                              0.999999
# 8                              1.000000
# 9                              1.000000
# 10                             1.000000
# 11                             1.000000
# 12                             1.000000
# 13                             1.000000
# 14                             1.000000
# 15                             1.000000

# %%
# Calculer les proportions cumulatives de variance expliquée
cumulative_variance_ratio_percent = pca.explained_variance_ratio_ * 100

# Tracer le graphique des proportions de variance expliquée en pourcentage
plt.figure(figsize=(10, 6))
plt.plot(
    range(1, len(pca.explained_variance_ratio_) + 1),
    pca.explained_variance_ratio_,
    marker="o",
    linestyle="-",
)
plt.title("Proportions de Variances Expliquées (en pourcentage)")
plt.xlabel("Nombre de Composantes Principales")
plt.ylabel("Pourcentage de Variance Expliquée")
plt.xticks(range(1, len(cumulative_variance_ratio_percent) + 1))
plt.grid(True)
plt.show()

# %%
n = X.shape[0]  # nb of individuals
p = X.shape[1]  # nb of variables
print(n, "  ", p)
eigval = (n - 1) / n * pca.explained_variance_  # eigen values
sqrt_eigval = np.sqrt(eigval)
corvar = np.zeros((p, p))  # empty matrix for coordinates
for k in range(p):
    corvar[:, k] = pca.components_[k, :] * sqrt_eigval[k]
# on modifie pour avoir un dataframe
coordvar = pd.DataFrame({"id": X.columns, "COR_1": corvar[:, 0], "COR_2": corvar[:, 1]})
coordvar
# Out:
# 32    16
#                                                    id     COR_1     COR_2
# 0                               Changement climatique  0.190601 -0.153509
# 1                Appauvrissement de la couche d'ozone  0.130778  0.180842
# 2                              Rayonnements ionisants  0.013841 -0.101466
# 3                     Formation photochimique d'ozone  0.163667  0.189884
# 4                                    Particules fines  0.382460 -0.108377
# 5   Effets toxicologiques sur la santé humaine   s...  0.060894  0.215212
# 6   Effets toxicologiques sur la santé humaine   s...  0.056479  0.224695
# 7              Acidification terrestre et eaux douces  0.323776 -0.129087
# 8                          Eutrophisation eaux douces  0.077123  0.202696
# 9                               Eutrophisation marine  0.292118  0.162415
# 10                           Eutrophisation terrestre  0.302311 -0.137733
# 11  Écotoxicité pour écosystèmes aquatiques d'eau ...  0.008480  0.232275
# 12                                 Utilisation du sol  0.225425 -0.170626
# 13                      Épuisement des ressources eau  0.287022  0.132317
# 14             Épuisement des ressources énergétiques  0.048024  0.192423
# 15                 Épuisement des ressources minéraux  0.005594  0.218378

# %%
moyennes_par_categorie
# Out:
# Sous-groupe d'aliment
# autres produits à base de viande    0.990059
# boissons sans alcool                0.034335
# charcuteries                        0.483717
# viandes crues                       0.554506
# viandes cuites                      0.810791
# Name: Changement climatique, dtype: float64

# %%
pca = PCA(n_components=3)  # Utiliser tous les composantes pour l'exemple
X_r = pca.fit_transform(X)


# Supposons que 'X_r' est le résultat de l'ACP et 'df_join_norm' contient les sous-groupes d'aliments
# Ajouter les sous-groupes d'aliments comme une nouvelle colonne dans les données réduites
X_r_df = pd.DataFrame(X_r, columns=["PC1", "PC2", "PC3"])
X_r_df["Sous-groupe d'aliment"] = df_join_norm["Sous-groupe d'aliment"].values

# Calculer les moyennes pour chaque sous-groupe
moyennes_par_categorie = X_r_df.groupby("Sous-groupe d'aliment").mean()

# Créer le graphique à barres groupées
fig, ax = plt.subplots(figsize=(12, 8))

# L'index pour les sous-groupes d'aliments
index = np.arange(len(moyennes_par_categorie))
bar_width = 0.2  # Largeur des barres
space_between_groups = 0.01  # Espace entre les groupes

# Créer une barre pour chaque composante principale
for i, pc in enumerate(["PC1", "PC2", "PC3"]):
    plt.bar(
        index + i * (bar_width + space_between_groups),
        moyennes_par_categorie[pc],
        bar_width,
        label=pc,
    )

# Ajouter des légendes et des titres
ax.set_xlabel("Sous-groupe d'Aliments")
ax.set_ylabel("Moyenne des Composantes Principales")
ax.set_title(
    "Comparaison des Impacts Environnementaux par Sous-groupe d'Aliments (Données ACP)"
)
ax.set_xticks(index + bar_width)
ax.set_xticklabels(moyennes_par_categorie.index)
ax.legend()

plt.xticks(
    rotation=0, ha="right"
)  # Rotation des étiquettes pour une meilleure lisibilité
plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
plt.show()

# %%
# Définir la taille du graphique
plt.figure(figsize=(12, 8))

# Utiliser les scores de la première composante principale comme couleurs
colors = X_r_df["PC1"]

# Tracer les points pour les deux composantes principales
plt.scatter(
    X_r_df.values[:, 0], X_r_df.values[:, 1], s=50, c=colors, cmap="viridis", alpha=0.5
)

# Ajouter des flèches pour les composantes principales et les annoter
for i in range(pca.components_.shape[1]):
    plt.arrow(
        0,
        0,
        pca.components_[0, i] * 12,
        pca.components_[1, i] * 11,
        alpha=0.5,
        head_width=0.1,
        head_length=0.1,
        fc="black",
        ec="black",
    )
    plt.text(
        pca.components_[0, i] * 10 * 1.15,
        pca.components_[1, i] * 10 * 1.15,
        X.columns[i],
        color="green",
        ha="center",
        va="center",
        fontsize=8,
    )

# Ajouter des titres et des étiquettes
plt.title("Biplot des deux premières composantes principales")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.colorbar()  # Ajouter une barre de couleur pour indiquer l'échelle

# Afficher le graphique
plt.grid(True)
plt.axis("equal")
plt.show()

# %%
# Créer un DataFrame pour les vecteurs propres
loadings = pd.DataFrame(
    pca.components_.T, columns=["PC1", "PC2", "PC3"], index=X.columns
)
loadings
# Out:
#                                                          PC1       PC2  \
# Changement climatique                               0.235204 -0.217191
# Appauvrissement de la couche d'ozone                0.161381  0.255863
# Rayonnements ionisants                              0.017080 -0.143559
# Formation photochimique d'ozone                     0.201967  0.268656
# Particules fines                                    0.471959 -0.153337
# Effets toxicologiques sur la santé humaine   su...  0.075143  0.304490
# Effets toxicologiques sur la santé humaine   su...  0.069695  0.317909
# Acidification terrestre et eaux douces              0.399542 -0.182638
# Eutrophisation eaux douces                          0.095170  0.286782
# Eutrophisation marine                               0.360476  0.229791
# Eutrophisation terrestre                            0.373054 -0.194871
# Écotoxicité pour écosystèmes aquatiques d'eau d...  0.010465  0.328632
# Utilisation du sol                                  0.278176 -0.241410
# Épuisement des ressources eau                       0.354188  0.187208
# Épuisement des ressources énergétiques              0.059263  0.272248
# Épuisement des ressources minéraux                  0.006902  0.308970
#
#                                                          PC3
# Changement climatique                               0.251940
# Appauvrissement de la couche d'ozone                0.095500
# Rayonnements ionisants                              0.909211
# Formation photochimique d'ozone                     0.096718
# Particules fines                                   -0.045224
# Effets toxicologiques sur la santé humaine   su...  0.057854
# Effets toxicologiques sur la santé humaine   su...  0.004628
# Acidification terrestre et eaux douces             -0.027782
# Eutrophisation eaux douces                          0.030389
# Eutrophisation marine                              -0.010705
# Eutrophisation terrestre                           -0.028039
# Écotoxicité pour écosystèmes aquatiques d'eau d...  0.013328
# Utilisation du sol                                 -0.102314
# Épuisement des ressources eau                      -0.150599
# Épuisement des ressources énergétiques              0.171023
# Épuisement des ressources minéraux                  0.144233

# %%
# Grouper les données par 'Sous-groupe d'aliment' et calculer la moyenne pour les indicateurs sélectionnés
moyennes_par_categorie = df_join_norm.groupby("Sous-groupe d'aliment").mean()


def plot_grouped_bar_chart(data, columns, group):
    # Nombre de groupes d'aliments
    n_groups = len(data.index)

    # Créer le graphique à barres groupées
    fig, ax = plt.subplots(figsize=(8, 5))

    # L'index pour les groupes d'aliments
    index = np.arange(n_groups)
    bar_width = 0.01  # Largeur des barres
    space_between_groups = 0.01  # Espace entre les groupes

    # Créer une barre pour chaque indicateur d'impact sélectionné
    for i, impact in enumerate(columns):
        plt.bar(
            index + i * (bar_width + space_between_groups),
            data[impact],
            bar_width,
            label=impact,
        )

    # Ajouter des légendes et des titres
    ax.set_ylabel("Scores EF Moyens")
    ax.set_title(f"Comparaison des Impacts Environnementaux pour {group}")
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(data.index)
    ax.legend(bbox_to_anchor=(1.24, 2), loc="upper left")

    plt.xticks(
        rotation=0, ha="center"
    )  # Rotation des étiquettes pour une meilleure lisibilité
    plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
    plt.show()


# Sélectionner les colonnes d'intérêt pour la comparaison
colonnes_impact_selectionnees = X.columns
# Utiliser la fonction pour créer le graphique à barres groupées
for group in df_join_norm["Sous-groupe d'aliment"].unique():
    data_subset = moyennes_par_categorie.loc[[group]]
    plot_grouped_bar_chart(data_subset, colonnes_impact_selectionnees, group)

# %%
moyennes_par_categorie

# %%
# Grouper les données par 'Sous-groupe d'aliment' et calculer la moyenne pour les indicateurs sélectionnés
moyennes_par_categorie = df_join_norm.groupby("Sous-groupe d'aliment").mean()


def plot_grouped_bar_chart(data, columns):
    # Nombre de groupes d'aliments
    n_groups = len(data.index)

    # Créer le graphique à barres groupées
    fig, ax = plt.subplots(figsize=(12, 6))

    # L'index pour les groupes d'aliments
    index = np.arange(n_groups)
    bar_width = 0.10  # Largeur des barres
    space_between_groups = 0.01  # Espace entre les groupes

    # Créer une barre pour chaque indicateur d'impact sélectionné
    for i, impact in enumerate(columns):
        plt.bar(
            index + i * (bar_width + space_between_groups),
            data[impact],
            bar_width,
            label=impact,
        )

    # Ajouter des légendes et des titres
    ax.set_xlabel("Sous-groupe d'Aliments")
    ax.set_ylabel("Scores Moyens")
    ax.set_title("Comparaison des Impacts Environnementaux par Sous-groupe d'Aliments")
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(moyennes_par_categorie.index)
    ax.legend()

    plt.xticks(
        rotation=0, ha="center"
    )  # Rotation des étiquettes pour une meilleure lisibilité
    plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
    plt.show()


# Sélectionner les colonnes d'intérêt pour la comparaison
colonnes_impact_selectionnees = [
    "Changement climatique",
    "Appauvrissement de la couche d'ozone",
    "Rayonnements ionisants",
    "Formation photochimique d'ozone",
    "Particules fines",
]

# Utiliser la fonction pour créer le graphique à barres groupées
for i in range(0, 3):
    if i == 2:
        colonnes_impact_selectionnees = X.columns[i * 5 :]
    else:
        colonnes_impact_selectionnees = X.columns[i * 5 : (i + 1) * 5]
    plot_grouped_bar_chart(moyennes_par_categorie, colonnes_impact_selectionnees)

# %%
import math


def plot_grouped_bar_chart(ax, data, columns, group, ymin, ymax):
    # Nombre de groupes d'aliments
    n_groups = len(data.index)

    # L'index pour les groupes d'aliments
    index = np.arange(n_groups)
    bar_width = 0.01  # Largeur des barres
    space_between_groups = 0.01  # Espace entre les groupes

    # Créer une barre pour chaque indicateur d'impact sélectionné
    for i, impact in enumerate(columns):
        ax.bar(
            index + i * (bar_width + space_between_groups),
            data[impact],
            bar_width,
            label=impact,
        )

    # Ajouter des légendes et des titres
    ax.set_ylabel("Scores EF Moyens")
    ax.set_title(f"Comparaison des Impacts Environnementaux pour {group}")
    # ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(data.index)

    ax.set_xticklabels(
        data.index, rotation=0, ha="center"
    )  # Rotation des étiquettes pour une meilleure lisibilité

    ax.set_ylim([ymin, ymax])  # Set the same y-axis limits for all subplots


# Sélectionner les colonnes d'intérêt pour la comparaison
colonnes_impact_selectionnees = X.columns

# Utiliser la fonction pour créer le graphique à barres groupées
groups = df_join_norm["Sous-groupe d'aliment"].unique()
n_plots = len(groups)
n_cols = 2
n_rows = math.ceil(n_plots / n_cols)

fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows), tight_layout=True)

for ax, group in zip(axs.flatten(), groups):
    data_subset = moyennes_par_categorie.loc[[group]]
    plot_grouped_bar_chart(ax, data_subset, colonnes_impact_selectionnees, group, 0, 1)

# Display the legend outside of the plot area and only once for all subplots
handles, labels = axs[0][0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Create a grid of subplots
fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(3, 2, width_ratios=[1, 1])

# Create the first plot on the first row
ax1 = plt.subplot(gs[0, 0])
group = groups[0]
data_subset = moyennes_par_categorie.loc[[group]]
plot_grouped_bar_chart(ax1, data_subset, colonnes_impact_selectionnees, group, 0, 1)

# Create the second and third plots on the second row
for i in range(1, 3):
    ax = plt.subplot(gs[1, i - 1])
    group = groups[i]
    data_subset = moyennes_par_categorie.loc[[group]]
    plot_grouped_bar_chart(ax, data_subset, colonnes_impact_selectionnees, group, 0, 1)

# Create the fourth and fifth plots on the third row
for i in range(3, 5):
    ax = plt.subplot(gs[2, i - 3])
    group = groups[i]
    data_subset = moyennes_par_categorie.loc[[group]]
    plot_grouped_bar_chart(ax, data_subset, colonnes_impact_selectionnees, group, 0, 1)

# Display the legend outside of the plot area and only once for all subplots
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")

plt.tight_layout()
plt.show()

# %%
# Supposons que 'moyennes_par_categorie' est votre DataFrame contenant les moyennes des impacts pour chaque sous-groupe d'aliments
seuil = 0.75

# Créer un dictionnaire pour stocker les impacts principaux pour chaque sous-groupe d'aliments
impacts_principaux = {}

# Parcourir chaque sous-groupe d'aliments
for sous_groupe, impacts in moyennes_par_categorie.iterrows():
    # Appliquer le seuil et récupérer les noms des impacts principaux
    impacts_principaux[sous_groupe] = list(
        impacts[impacts >= seuil * impacts.max()].index
    )

# Convertir le dictionnaire en DataFrame pour un affichage sous forme de tableau
df_impacts_principaux = pd.DataFrame(
    impacts_principaux.items(),
    columns=["Sous-groupe d'aliments", "Impacts Principaux"],
)

# Afficher le DataFrame
df_impacts_principaux

# %%
df_impacts_principaux.iloc[3, 1]

# %% [markdown]
# ```markdown
# ### Changement climatique

# %%
df_jointure.groupby("Sous-groupe d'aliment").count()

# %%
df_jointure.columns[39:45]
# 51:57

# %%
df_viande_cuite = df_jointure[df_jointure["Sous-groupe d'aliment"] == "viandes cuites"]
cols = ["Code CIQUAL"]
cols += list(df_jointure.columns[39:45])
df_viande_cuite = df_viande_cuite[cols]
df_viande_cuite

# %%
import scipy.stats as stats

f_value, p_value = stats.f_oneway(
    df_viande_cuite["Changement climatique - Transformation"],
    df_viande_cuite["Changement climatique - Emballage"],
    df_viande_cuite["Changement climatique - Transport"],
    df_viande_cuite["Changement climatique - Supermarché et distribution"],
    df_viande_cuite["Changement climatique - Consommation"],
)

# Afficher les résultats du test ANOVA
print(f"F-value: {f_value}, P-value: {p_value}")

# Si le P-value est inférieur à 0.05, cela indique des différences significatives
if p_value < 0.05:
    print("Des différences significatives existent entre les groupes.")
else:
    print("Aucune différence significative n'a été trouvée entre les groupes.")

# %%
# Calculer la somme ou la moyenne des impacts pour chaque étape
impact_transformation = df_viande_cuite["Changement climatique - Transformation"].mean()
impact_emballage = df_viande_cuite["Changement climatique - Emballage"].mean()
impact_transport = df_viande_cuite["Changement climatique - Transport"].mean()
impact_supermarche = df_viande_cuite[
    "Changement climatique - Supermarché et distribution"
].mean()
impact_consommation = df_viande_cuite["Changement climatique - Consommation"].mean()

# Créer un dictionnaire pour stocker les résultats
impacts = {
    "Transformation": impact_transformation,
    "Emballage": impact_emballage,
    "Transport": impact_transport,
    "Supermarché et distribution": impact_supermarche,
    "Consommation": impact_consommation,
}

# Trouver l'étape avec le plus grand impact
etape_plus_impact = max(impacts, key=impacts.get)

# Afficher l'étape avec le plus grand impact
print(
    f"L'étape ayant le plus grand impact sur le changement climatique est : {etape_plus_impact} avec une moyenne de {impacts[etape_plus_impact]}"
)
impacts

# %%
# Trouver l'étape avec le plus grand impact
etape_plus_impact = max(impacts, key=impacts.get)
max_value = impacts[etape_plus_impact]

# Créer le graphique à barres
plt.figure(figsize=(10, 6))
bars = plt.bar(impacts.keys(), impacts.values(), color="skyblue", width=0.4)

# Ajouter des pointillés pour marquer l'étape avec le plus grand impact
plt.axhline(y=max_value, color="grey", linestyle="--", linewidth=1)
plt.text(
    0.10,
    max_value,
    f"Maximum Impact: {max_value:.2f}",
    color="black",
    va="bottom",
    ha="center",
)

# Mettre en évidence la barre avec le plus grand impact
bars[list(impacts.keys()).index(etape_plus_impact)].set_color("red")

# Ajouter des titres et des étiquettes
plt.title(
    "Impact sur le Changement Climatique par Étape du Cycle de Vie (Viandes Cuites)"
)
plt.xlabel("Étapes du Cycle de Vie")
plt.ylabel("Impact Moyen sur le Changement Climatique")
plt.xticks(
    rotation=0, ha="center"
)  # Rotation des étiquettes pour une meilleure lisibilité

# Afficher le graphique
plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
plt.show()

# %%
def impact_aliment(
    columns=[], sg_aliment="viandes cuites", df_jointure=df_jointure, title=""
):
    df_sg = df_jointure[df_jointure["Sous-groupe d'aliment"] == sg_aliment]
    cols = ["Code CIQUAL"]
    cols += list(columns)
    df_sg = df_sg[cols]
    df_sg

    f_value, p_value = stats.f_oneway(
        df_sg[columns[0]],
        df_sg[columns[1]],
        df_sg[columns[2]],
        df_sg[columns[3]],
        df_sg[columns[4]],
        df_sg[columns[5]],
    )

    # Afficher les résultats du test ANOVA
    print(f"F-value: {f_value}, P-value: {p_value}")

    # Si le P-value est inférieur à 0.05, cela indique des différences significatives
    if p_value < 0.05:
        print("Des différences significatives existent entre les groupes.")
    else:
        print("Aucune différence significative n'a été trouvée entre les groupes.")

    # Calculer la somme ou la moyenne des impacts pour chaque étape
    impact_argiculture = df_sg[columns[0]].mean()
    impact_transformation = df_sg[columns[1]].mean()
    impact_emballage = df_sg[columns[2]].mean()
    impact_transport = df_sg[columns[3]].mean()
    impact_supermarche = df_sg[columns[4]].mean()
    impact_consommation = df_sg[columns[5]].mean()

    # Créer un dictionnaire pour stocker les résultats
    impacts = {
        "Agriculture": impact_argiculture,
        "Transformation": impact_transformation,
        "Emballage": impact_emballage,
        "Transport": impact_transport,
        "Supermarché et distribution": impact_supermarche,
        "Consommation": impact_consommation,
    }

    # Trouver l'étape avec le plus grand impact
    etape_plus_impact = max(impacts, key=impacts.get)

    print(impacts)

    # Afficher l'étape avec le plus grand impact
    print(
        f"L'étape ayant le plus grand impact sur {title} est : {etape_plus_impact} avec une moyenne de {impacts[etape_plus_impact]}"
    )

    # Trouver l'étape avec le plus grand impact
    etape_plus_impact = max(impacts, key=impacts.get)
    max_value = impacts[etape_plus_impact]

    # Créer le graphique à barres
    plt.figure(figsize=(10, 6))
    bars = plt.bar(impacts.keys(), impacts.values(), color="skyblue", width=0.4)

    # Ajouter des pointillés pour marquer l'étape avec le plus grand impact
    plt.axhline(y=max_value, color="grey", linestyle="--", linewidth=1)
    plt.text(
        0.10,
        max_value,
        f"Maximum Impact: {max_value:.2f}",
        color="black",
        va="bottom",
        ha="center",
    )

    # Mettre en évidence la barre avec le plus grand impact
    bars[list(impacts.keys()).index(etape_plus_impact)].set_color("red")

    # Ajouter des titres et des étiquettes
    plt.title(f"Impact sur {title} par Étape du Cycle de Vie ({sg_aliment})")
    plt.xlabel("Étapes du Cycle de Vie")
    plt.ylabel(f"Impact Moyen sur {title}")
    plt.xticks(
        rotation=0, ha="center"
    )  # Rotation des étiquettes pour une meilleure lisibilité

    # Afficher le graphique
    plt.tight_layout()  # Ajuste automatiquement les paramètres de la figure pour donner de l'espace aux étiquettes
    plt.show()


impact_aliment(
    columns=df_jointure.columns[39:45],
    sg_aliment="viandes crues",
    df_jointure=df_jointure,
    title="le Changement Climatique",
)

# %%
df_jointure.columns[51:57]

# %%
impact_aliment(
    columns=df_jointure.columns[51:57],
    sg_aliment="viandes cuites",
    df_jointure=df_jointure,
    title="le Rayonnements ionisants",
)

# %%
df_jointure.columns[81:87]

# %%
impact_aliment(
    columns=df_jointure.columns[81:87],
    sg_aliment="viandes cuites",
    df_jointure=df_jointure,
    title="l'Acidification terrestre et eaux douces",
)

# %%
df_jointure.columns[99:105]

# %%
impact_aliment(
    columns=df_jointure.columns[99:105],
    sg_aliment="viandes crues",
    df_jointure=df_jointure,
    title="l'Eutrophisation terrestre",
)

# %%
df_jointure.columns[111:117]

# %%
impact_aliment(
    columns=df_jointure.columns[111:117],
    sg_aliment="viandes crues",
    df_jointure=df_jointure,
    title="l'Utilisation du sol",
)

# %%
colonnes_selectionnees = [
    "Changement climatique",
    "Effets toxicologiques sur la santé humaine   substances non-cancérogènes",
    "Effets toxicologiques sur la santé humaine   substances cancérogènes",
    "Écotoxicité pour écosystèmes aquatiques d'eau douce",
    "Utilisation du sol",
    "Épuisement des ressources eau",
    "Épuisement des ressources énergétiques",
    "Épuisement des ressources minéraux",
]

# treshold sur la colonne score unique EF
median_value = df_synt["Score unique EF"].median()
labels = np.where(df_synt["Score unique EF"] > median_value, 1, 0)

X = df_synt[colonnes_selectionnees]

print("valeurs 1", len(labels[labels == 1]))
print("valeurs 0", len(labels[labels == 0]))
# Out:
# valeurs 1 1211
# valeurs 0 1212

# %%
# Refaire l'ACP avec les données normalisées
pca = PCA(n_components=2)
X = df_synt[df_synt.columns[13:29]]
print(X.shape)
X_r = pca.fit_transform(X)

# Afficher les dimensions et les proportions de variance expliquée
summary_table = pd.DataFrame(
    columns=[
        "Dimension",
        "Explained Variance",
        "Explained Variance Ratio",
        "Cumulative Explained Variance Ratio",
    ]
)

# Créer une liste pour stocker les lignes du tableau récapitulatif
rows = []

# Calculer les proportions cumulatives de variance expliquée
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Remplir la liste avec les informations sur chaque dimension
for i in range(len(pca.explained_variance_)):
    rows.append(
        {
            "Dimension": i + 1,
            "Explained Variance": pca.explained_variance_[i],
            "Explained Variance Ratio": pca.explained_variance_ratio_[i],
            "Cumulative Explained Variance Ratio": cumulative_variance_ratio[i],
        }
    )

# Créer le DataFrame récapitulatif en concaténant les lignes
summary_table = pd.concat([pd.DataFrame([row]) for row in rows], ignore_index=True)
summary_table
# Out:
# (2423, 16)
#    Dimension  Explained Variance  Explained Variance Ratio  \
# 0          1       437854.216389                  0.986072
# 1          2         4101.971905                  0.009238
#
#    Cumulative Explained Variance Ratio
# 0                             0.986072
# 1                             0.995310

# %%
print(X_r.shape)
# Out:
# (2423, 2)

# %%
# Regressions logistiques
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_score,
    roc_curve,
    roc_auc_score,
)
from sklearn.model_selection import cross_val_score


def display_results(lr_model, X_test, y_test, y_pred, colonnes_selectionnees):
    # Affichage du rapport de classification
    print(classification_report(y_test, y_pred, target_names=["faibe", "fort"]))

    # Affichage de la matrice de confusion
    conf_mat = confusion_matrix(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax)
    ax.set_xlabel("Prédit")
    ax.set_ylabel("Vrai")
    ax.set_title("Matrice de confusion")
    ax.xaxis.set_ticklabels(["faible", "fort"])
    ax.yaxis.set_ticklabels(["faible", "fort"])
    plt.show()

    # # Affichage des coefficients
    # coefficients = lr_model.coef_[0]
    # coefficients = pd.DataFrame(
    #     coefficients, index=colonnes_selectionnees, columns=["Coefficient"]
    # )
    # print(coefficients)

    # Courbe ROC
    # Calcul des probabilités prédites
    y_pred_proba = lr_model.predict_proba(X_test)[:, 1]

    # Calcul de la courbe ROC
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

    # Calcul de l'aire sous la courbe ROC
    auc = roc_auc_score(y_test, y_pred_proba)

    # Création de la courbe ROC
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color="darkorange", lw=2, label="ROC curve (area = %0.2f)" % auc)
    plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("Taux de faux positifs")
    plt.ylabel("Taux de vrais positifs")
    plt.title("Courbe ROC")
    plt.legend(loc="lower right")
    plt.show()

# %%
# Division des données en ensemble d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(
    X_r, labels, test_size=0.2, random_state=0
)

# Création du modèle de régression logistique
lr_model = LogisticRegression(max_iter=1000)

# Cross validation
scores = cross_val_score(lr_model, X_train, y_train, cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# Entraînement du modèle
lr_model.fit(X_train, y_train)

# Prédiction sur l'ensemble de test
y_pred = lr_model.predict(X_test)

print("acc : ", precision_score(y_test, y_pred))

precision_lr = np.where(y_test == y_pred, 1, 0)

# Affichage des résultats
display_results(lr_model, X_test, y_test, y_pred, colonnes_selectionnees)
# Out:
# Accuracy: 0.93 (+/- 0.01)
# acc :  0.9752066115702479
#               precision    recall  f1-score   support
#
#        faibe       0.96      0.97      0.97       239
#         fort       0.98      0.96      0.97       246
#
#     accuracy                           0.97       485
#    macro avg       0.97      0.97      0.97       485
# weighted avg       0.97      0.97      0.97       485

# %%
# SVM
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Création du modèle SVM
svm_model = SVC(probability=True)

# Paramètres à tester
param_grid = {
    "C": [1],
    "kernel": ["linear"],
}

# Recherche des meilleurs paramètres
grid = GridSearchCV(svm_model, param_grid, refit=True, verbose=2)
grid.fit(X_train, y_train)

# Meilleurs paramètres
print(grid.best_params_)

# Prédiction sur l'ensemble de test
y_pred_svm = grid.predict(X_test)
print("accuracy:", grid.score(X_test, y_test))

precision_svm = np.where(y_test == y_pred_svm, 1, 0)

# Affichage des résultats
display_results(grid, X_test, y_test, y_pred_svm, colonnes_selectionnees)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .................................C=1, kernel=linear; total time=  12.7s
# [CV] END .................................C=1, kernel=linear; total time=   7.1s
# [CV] END .................................C=1, kernel=linear; total time=   8.7s
# [CV] END .................................C=1, kernel=linear; total time=   9.9s
# [CV] END .................................C=1, kernel=linear; total time=   7.4s
# {'C': 1, 'kernel': 'linear'}
# accuracy: 0.9670103092783505
#               precision    recall  f1-score   support
#
#        faibe       0.96      0.97      0.97       239
#         fort       0.98      0.96      0.97       246
#
#     accuracy                           0.97       485
#    macro avg       0.97      0.97      0.97       485
# weighted avg       0.97      0.97      0.97       485

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

# Création du modèle Random Forest
rf_model = RandomForestClassifier()

# Entraînement du modèle
rf_model.fit(X_train, y_train)

# Prédiction sur l'ensemble de test
y_pred_rf = rf_model.predict(X_test)

print("accuracy:", rf_model.score(X_test, y_test))

precision_rf = np.where(y_test == y_pred_rf, 1, 0)

# Affichage des résultats
display_results(rf_model, X_test, y_test, y_pred_rf, colonnes_selectionnees)
# Out:
# accuracy: 0.9711340206185567
#               precision    recall  f1-score   support
#
#        faibe       0.96      0.98      0.97       239
#         fort       0.98      0.96      0.97       246
#
#     accuracy                           0.97       485
#    macro avg       0.97      0.97      0.97       485
# weighted avg       0.97      0.97      0.97       485

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

# Création du modèle Decision Tree
dt_model = DecisionTreeClassifier()

# Entraînement du modèle
dt_model.fit(X_train, y_train)


# Prédiction sur l'ensemble de test
y_pred_dt = dt_model.predict(X_test)
print("accuracy:", dt_model.score(X_test, y_test))
precision_dt = np.where(y_test == y_pred_dt, 1, 0)

# Affichage des résultats
display_results(dt_model, X_test, y_test, y_pred_dt, colonnes_selectionnees)
# Out:
# accuracy: 0.9649484536082474
#               precision    recall  f1-score   support
#
#        faibe       0.96      0.97      0.96       239
#         fort       0.97      0.96      0.97       246
#
#     accuracy                           0.96       485
#    macro avg       0.96      0.97      0.96       485
# weighted avg       0.97      0.96      0.96       485

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier

# Création du modèle KNN
knn_model = KNeighborsClassifier()

# Entraînement du modèle
knn_model.fit(X_train, y_train)

# Prédiction sur l'ensemble de test
y_pred_knn = knn_model.predict(X_test)
print("accuracy:", knn_model.score(X_test, y_test))
precision_knn = np.where(y_test == y_pred_knn, 1, 0)

# Affichage des résultats
display_results(knn_model, X_test, y_test, y_pred_knn, colonnes_selectionnees)
# Out:
# accuracy: 0.9711340206185567
#               precision    recall  f1-score   support
#
#        faibe       0.97      0.97      0.97       239
#         fort       0.97      0.97      0.97       246
#
#     accuracy                           0.97       485
#    macro avg       0.97      0.97      0.97       485
# weighted avg       0.97      0.97      0.97       485

# %%
def display_roc_curves(models, preds, X_test, y_test):
    import matplotlib.pyplot as plt
    from sklearn.metrics import roc_curve, roc_auc_score

    plt.figure(figsize=(6, 6))

    # Boucle sur les modèles et les prédictions
    for model, y_pred in zip(models, preds):
        # Calcul des probabilités prédites
        y_pred_proba = model.predict_proba(X_test)[:, 1]

        # Calcul de la courbe ROC
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

        # Calcul de l'aire sous la courbe ROC
        auc = roc_auc_score(y_test, y_pred_proba)

        # Création de la courbe ROC

        if isinstance(model, GridSearchCV):
            label = "ROC curve (area = %0.2f) for SVM" % auc
        else:
            label = "ROC curve (area = %0.2f) for %s" % (auc, type(model).__name__)

        plt.plot(fpr, tpr, lw=2, label=label)

    # Ajout de la ligne diagonale
    plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("Taux de faux positifs")
    plt.ylabel("Taux de vrais positifs")
    plt.title("Courbe ROC")
    plt.legend(loc="lower right")
    plt.show()

# %%
display_roc_curves(
    [lr_model, grid, rf_model, dt_model, knn_model],
    [y_pred, y_pred_svm, y_pred_rf, y_pred_dt, y_pred_knn],
    X_test,
    y_test,
)

# %%
len(precision_svm)
# Out:
# 485

# %%
from scipy.stats import ttest_rel
from sklearn.metrics import precision_score
import pandas as pd

model_names = ["Logistic Regression", "SVM", "Random Forest", "Decision Tree", "KNN"]

# Calcul de la précision pour chaque modèle
precisions = [precision_lr, precision_svm, precision_rf, precision_dt, precision_knn]

# Calcul du test t de Student apparié pour chaque paire de modèles
t_stats = []
p_vals = []
model1_list = []
model2_list = []
hypothesis_results = []
alpha = 0.05
for i in range(len(precisions)):
    for j in range(i + 1, len(precisions)):
        t_stat, p_val = ttest_rel(precisions[i], precisions[j])
        model1_list.append(model_names[i])
        model2_list.append(model_names[j])
        t_stats.append(t_stat)
        p_vals.append(p_val)
        hypothesis_results.append("Reject H0" if p_val < alpha else "Fail to reject H0")

# Création d'un DataFrame pour l'affichage
df = pd.DataFrame(
    {
        "Model-1": model1_list,
        "Model-2": model2_list,
        "t-statistic": t_stats,
        "p-value": p_vals,
        "Hypothesis Result": hypothesis_results,
    }
)

display(df)
# Out:
#                Model-1        Model-2  t-statistic   p-value  \
# 0  Logistic Regression            SVM          NaN       NaN
# 1  Logistic Regression  Random Forest    -0.499613  0.617575
# 2  Logistic Regression  Decision Tree     0.229192  0.818817
# 3  Logistic Regression            KNN    -0.499613  0.617575
# 4                  SVM  Random Forest    -0.499613  0.617575
# 5                  SVM  Decision Tree     0.229192  0.818817
# 6                  SVM            KNN    -0.499613  0.617575
# 7        Random Forest  Decision Tree     1.342751  0.179982
# 8        Random Forest            KNN     0.000000  1.000000
# 9        Decision Tree            KNN    -0.904364  0.366252
#
#    Hypothesis Result
# 0  Fail to reject H0
# 1  Fail to reject H0
# 2  Fail to reject H0
# 3  Fail to reject H0
# 4  Fail to reject H0
# 5  Fail to reject H0
# 6  Fail to reject H0
# 7  Fail to reject H0
# 8  Fail to reject H0
# 9  Fail to reject H0
